# %%
from nilearn import datasets, plotting, image
import nibabel as nib
from nilearn.maskers import NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure
from nilearn.interfaces.fmriprep import load_confounds
import numpy as np
import os
import pandas as pd

import torch.nn.functional as F
from torch.nn import Sequential, Linear, ReLU, GRU, BatchNorm1d
from torch_geometric.nn import EdgeConv, GCNConv, GraphConv
from torch_geometric.nn import global_mean_pool
from torch_geometric.data import InMemoryDataset, Data, DataLoader
from torch_geometric.utils import from_networkx

import networkx as nx
from networkx.convert_matrix import from_numpy_array

import torch
from torch.nn import Linear, Parameter
from torch_geometric.nn import MessagePassing
import torch_geometric as tg

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

import wandb
import random
import functions as f
import torch
import torch.nn.functional as F
from torch_geometric.data import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool

# %%
#generate correlation functions
corr_matrices_root = 'ADNI_full/corr_matrices'
full_corr_path_list = sorted(os.listdir(corr_matrices_root))
corr_matrices_full = []
for i in range(len(full_corr_path_list)):
    path = os.path.join(corr_matrices_root, full_corr_path_list[i])
    corr_matrices_full.append(np.loadtxt(path, delimiter=','))

# %%
#generate the label files
labels_full = np.loadtxt('ADNI_full/label_full.csv', dtype=str, delimiter=',')

# %%
##remove "SMC" values
idx = f.filter_SMC_patient_info()
corr_matrices = [corr_matrices_full[i] for i in idx]
labels = [labels_full[i] for i in idx]
for i in range(len(labels)):
    if labels[i] == 'CN':
        labels[i] = 0

    elif labels[i] == 'EMCI' or labels[i] == 'MCI' or labels[i] == 'LMCI':
        labels[i] = 1

    elif labels[i] == 'AD':
        labels[i] = 2

    else:
        print('Error: incorrect label')

# %%
#binary classification
cn = filter_group('CN')
ad = filter_group('AD')
bin_idx = sorted(cn + ad)
corr_matrices = [corr_matrices_full[i] for i in bin_idx]
labels = [labels_full[i] for i in bin_idx]
for i in range(len(labels)):
    if labels[i] == 'CN':
        labels[i] = 0

    elif labels[i] == 'AD':
        labels[i] = 1

    else:
        print('Error: incorrect label')

# %%
assert len(labels) == len(corr_matrices)

# %%
class ADNI_dataset(InMemoryDataset):
    def __init__(self, root, transform=None, pre_transform=None, threshold=0.4):
        self.threshold = threshold
        super().__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def processed_file_names(self):
        return ['data.pt']

    def process(self):
        """ Converts raw data into GNN-readable format by constructing
        graphs out of connectivity matrices.

        """
        graphs=[]
        for i in range(len(corr_matrices)):
            corr_matrix = corr_matrices[i]
            n_rois = corr_matrix.shape[0]
            edge_matrix = np.zeros((n_rois,n_rois))
            for j in range(n_rois):
                for k in range(n_rois):
                    if np.abs(corr_matrix[ j , k ]) < self.threshold:
                        edge_matrix[ j , k ] = 0
                    else:
                        edge_matrix[ j , k ] = corr_matrix[ j , k]

            corr_matrix_nx = from_numpy_array(edge_matrix)

            deg_dict = dict(corr_matrix_nx.degree())
            bc_dict = nx.betweenness_centrality(corr_matrix_nx)
            cc_dict = nx.clustering(corr_matrix_nx)
            # Compute the global efficiency of the graph
            ge = nx.global_efficiency(corr_matrix_nx)

            le_dict = {}

            # loop over all nodes in the graph
            for node in corr_matrix_nx.nodes():
                # find the subgraph of neighbors of the current node
                subgraph = corr_matrix_nx.subgraph(corr_matrix_nx.neighbors(node))

                # calculate the efficiency of the subgraph
                if subgraph.number_of_nodes() > 1:
                    efficiency = nx.global_efficiency(subgraph)
                else:
                    efficiency = 0.0

                # store the efficiency in the dictionary
                le_dict[node] = efficiency


            # Compute the participation coefficient and ratio of local to global efficiency of each node
            ratio_le_ge = np.array(list(le_dict.values())) / ge

            # Convert the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency dictionaries to NumPy arrays
            deg_array = np.array(list(deg_dict.values()))
            bc_array = np.array(list(bc_dict.values()))
            le_array = np.array(list(le_dict.values()))



            cc_array = np.array(list(cc_dict.values()))
            ratio_le_ge_array = ratio_le_ge

            # Normalize the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency arrays to have zero mean and unit variance
            deg_array_norm = (deg_array - np.mean(deg_array)) / np.std(deg_array)
            bc_array_norm = (bc_array - np.mean(bc_array)) / np.std(bc_array)
            le_array_norm = (le_array - np.mean(le_array)) / np.std(le_array)
            ratio_le_ge_array_norm = (ratio_le_ge_array - np.mean(ratio_le_ge_array)) / np.std(ratio_le_ge_array)
            cc_array_norm = (cc_array - np.mean(cc_array)) / np.std(cc_array)

            # Concatenate the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency arrays to form a single feature vector
            x_conc = torch.tensor(np.concatenate((deg_array_norm, bc_array_norm, le_array_norm, cc_array_norm, ratio_le_ge_array_norm)), dtype=torch.float)
            x = torch.reshape(x_conc , (5 , n_rois)).T


            corr_matrix_data = from_networkx(corr_matrix_nx)
            corr_matrix_data.x = x
            corr_matrix_data.y = labels[i]
            #pcorr_matrix_data.pos = coordinates

            # Add to running list of all dataset items
            graphs.append(corr_matrix_data)

        data, slices = self.collate(graphs)
        torch.save((data, slices), self.processed_paths[0])
# Out:
# 78

# %%
dataset = ADNI_dataset('ADNI_0.5')

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, dropout, input_dim ,output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, output_dim)
        self.dropout = dropout

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.relu(self.conv3(x, edge_index))
        x = global_mean_pool(x, batch)
        x = self.fc(x)
        return F.log_softmax(x, dim=1)
# Out:
# Dataset: ADNI_dataset(78):
# ====================
# Number of graphs: 78
# Number of features: 5
# Number of classes: 2
#
# Data(edge_index=[2, 444], weight=[444], x=[116, 5], y=[1], num_nodes=116)
# =============================================================
# Number of nodes: 116
# Number of edges: 444
# Average node degree: 3.83
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: True

# %%
def train():
    model.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
         #out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         out = model(data)
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.#
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
tot_test_acc = []
kf = StratifiedKFold(n_splits=5, shuffle=False)
for train_val_idx, test_idx in kf.split(dataset, dataset.data.y):
    X_train_val = [dataset[i] for i in train_val_idx]
    X_test      = [dataset[i] for i in test_idx]
    Y_train_val = [dataset.data.y[i] for i in train_val_idx]
    Y_test      = [dataset.data.y[i] for i in test_idx]

    X_train, X_valid, Y_train, Y_valid = train_test_split(X_train_val, Y_train_val , test_size=0.125,
                                                    random_state=42, stratify=Y_train_val)

    print(f'Number of training graphs: {len(X_train)}')
    print(f'Number of validation graphs: {len(X_valid)}')
    print(f'Number of test graphs: {len(X_test)}')

    lab = [0 , 1 , 2]
    class_freq = []
    for i in lab:
        class_freq.append(np.count_nonzero(torch.Tensor(Y_train) == i))
    class_freq = torch.FloatTensor(class_freq)
    class_weights = 1 / class_freq
    class_weights /= class_weights.sum()

    train_loader = DataLoader(X_train, batch_size=16, shuffle=True)
    valid_loader = DataLoader(X_valid, batch_size=len(X_valid), shuffle=True)
    test_loader = DataLoader(X_test, batch_size=len(X_test), shuffle=False)

    model = GCN(hidden_channels=8, dropout=0.5, input_dim=dataset.num_node_features, output_dim=dataset.num_classes)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

    model.train()
    for epoch in range(200):
        total_loss = 0
        for data in train_loader:
            optimizer.zero_grad()
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * data.num_graphs
            model.eval()
            correct = 0
            for data_v in valid_loader:
                out = model(data_v.x, data_v.edge_index, data_v.batch)
                pred = out.argmax(dim=1)
                print(pred)
                correct += int((pred == data_v.y).sum())
            acc = correct / len(valid_loader.dataset)
        print(f'Epoch {epoch}, Loss {total_loss / len(dataset)}, Valid Accuracy: {acc:.4f}')


    model.eval()
    correct = 0
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch)
        pred = out.argmax(dim=1)
        correct += int((pred == data.y).sum())
    acc = correct / len(test_loader.dataset)
    print(f'Test Accuracy: {acc:.4f}')
    tot_test_acc.append(acc)

print(f'Average Test Accuracy: {sum(tot_test_acc) / len(tot_test_acc)}')
print(f'Max test accuracy: {max(tot_test_acc)}')
print(f'Standard Deviation: {np.std(tot_test_acc)}')

# %%
def filter_group(group):
    df = pd.read_csv('/Users/georgepulickal/Documents/ADNI_FULL/patient_info.csv')
    labels = df['Research Group']
    label_idx_list = [i for i in range(len(labels)) if labels[i] == group]
    return label_idx_list
# Out:
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# Epoch 0, Loss 0.48186945609557325, Train Accuracy: 0.5556, Valid Accuracy: 0.6250
# Epoch 1, Loss 0.4794714404986455, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 2, Loss 0.4788187757516519, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 3, Loss 0.4785492970393254, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 4, Loss 0.4781373815658765, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 5, Loss 0.47900850956256574, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 6, Loss 0.4784015783896813, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 7, Loss 0.47907828214841014, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 8, Loss 0.4754462012877831, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 9, Loss 0.4749109775592119, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.4745851907974634, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.4741503214224791, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.47283442662312436, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.47258224854102504, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 14, Loss 0.47045554106052107, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 15, Loss 0.47059313303385025, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 16, Loss 0.4670823980600406, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 17, Loss 0.46500968016110933, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 18, Loss 0.4633348905123197, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 19, Loss 0.46252778248909193, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 20, Loss 0.4584368497897417, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 21, Loss 0.45686656083816135, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 22, Loss 0.45343719995938814, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 23, Loss 0.45693435118748593, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 24, Loss 0.46344395784231335, Train Accuracy: 0.5556, Valid Accuracy: 0.5000
# Epoch 25, Loss 0.4535615887397375, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 26, Loss 0.4473946308478331, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 27, Loss 0.4403031957455171, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 28, Loss 0.4368748405040839, Train Accuracy: 0.6667, Valid Accuracy: 0.6250
# Epoch 29, Loss 0.4497409210755275, Train Accuracy: 0.6667, Valid Accuracy: 0.6250
# Epoch 30, Loss 0.4289195736249288, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 31, Loss 0.42594031798533905, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 32, Loss 0.4213621234282469, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 33, Loss 0.4260836579860785, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 34, Loss 0.42401740948359173, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 35, Loss 0.4402171709598639, Train Accuracy: 0.5370, Valid Accuracy: 0.5000
# Epoch 36, Loss 0.3996805212436578, Train Accuracy: 0.7037, Valid Accuracy: 0.6250
# Epoch 37, Loss 0.42508319402352357, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 38, Loss 0.409950227309496, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 39, Loss 0.4297263683416905, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 40, Loss 0.39809753955938876, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 41, Loss 0.4032312157826546, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 42, Loss 0.3884303844892062, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 43, Loss 0.3816613868260995, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 44, Loss 0.37391912937164307, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 45, Loss 0.3711999310896947, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 46, Loss 0.3744638088421944, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 47, Loss 0.37088671250221056, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 48, Loss 0.3860236131227933, Train Accuracy: 0.6481, Valid Accuracy: 0.6250
# Epoch 49, Loss 0.3757443871253576, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 50, Loss 0.37029544359598404, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 51, Loss 0.37138678018863386, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 52, Loss 0.384728199396378, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 53, Loss 0.3636688849864862, Train Accuracy: 0.7407, Valid Accuracy: 0.6250
# Epoch 54, Loss 0.3516376920235463, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 55, Loss 0.3625426735633459, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 56, Loss 0.34345522561134434, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 57, Loss 0.3278471346084888, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 58, Loss 0.3384640553058722, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 59, Loss 0.3427598843207726, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 60, Loss 0.33963089570021016, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 61, Loss 0.30642033387453127, Train Accuracy: 0.8148, Valid Accuracy: 0.6250
# Epoch 62, Loss 0.34332576394081116, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 63, Loss 0.31229732586787295, Train Accuracy: 0.8148, Valid Accuracy: 0.6250
# Epoch 64, Loss 0.3570184615942148, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 65, Loss 0.3062100181212792, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 66, Loss 0.3189488955033131, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 67, Loss 0.2861511401641063, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 68, Loss 0.28769385050504637, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 69, Loss 0.27545299667578477, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 70, Loss 0.2836983769367903, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 71, Loss 0.2704379818378351, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 72, Loss 0.28015737044505584, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 73, Loss 0.3052562207747728, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 74, Loss 0.2554899866764362, Train Accuracy: 0.8704, Valid Accuracy: 0.5000
# Epoch 75, Loss 0.2706668537396651, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 76, Loss 0.25412719142742646, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 77, Loss 0.24785932363607946, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 78, Loss 0.25603790160937184, Train Accuracy: 0.8704, Valid Accuracy: 0.5000
# Epoch 79, Loss 0.2438903175867521, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 80, Loss 0.2332439063451229, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 81, Loss 0.2389677113447434, Train Accuracy: 0.8704, Valid Accuracy: 0.5000
# Epoch 82, Loss 0.2198026913862962, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 83, Loss 0.2195449383595051, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 84, Loss 0.2111773017125252, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 85, Loss 0.21125734310883743, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 86, Loss 0.2196164818910452, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 87, Loss 0.2121550738811493, Train Accuracy: 0.8704, Valid Accuracy: 0.2500
# Epoch 88, Loss 0.20609008845610496, Train Accuracy: 0.8889, Valid Accuracy: 0.6250
# Epoch 89, Loss 0.18786140894278502, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 90, Loss 0.1765293081601461, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 91, Loss 0.20001231554226997, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 92, Loss 0.2109036224010663, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 93, Loss 0.18921395104665023, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 94, Loss 0.1721846973284697, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 95, Loss 0.16291823830360022, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 96, Loss 0.1552234078064943, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 97, Loss 0.15155082291517502, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 98, Loss 0.15426219464876714, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 99, Loss 0.15354528029759726, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 100, Loss 0.16157956612415802, Train Accuracy: 0.9074, Valid Accuracy: 0.6250
# Epoch 101, Loss 0.21037382021164283, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 102, Loss 0.28132261679722714, Train Accuracy: 0.7778, Valid Accuracy: 0.6250
# Epoch 103, Loss 0.29938788062486893, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 104, Loss 0.27788710861633986, Train Accuracy: 0.8333, Valid Accuracy: 0.6250
# Epoch 105, Loss 0.16762749697917548, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 106, Loss 0.15617530850263742, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 107, Loss 0.1772817678940602, Train Accuracy: 0.9074, Valid Accuracy: 0.6250
# Epoch 108, Loss 0.14719290343614724, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 109, Loss 0.14491070806980133, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 110, Loss 0.13887580312215364, Train Accuracy: 0.9074, Valid Accuracy: 0.6250
# Epoch 111, Loss 0.13717714028480726, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 112, Loss 0.12726753797286597, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 113, Loss 0.12499441970617343, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 114, Loss 0.11647009123594333, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 115, Loss 0.12350927293300629, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 116, Loss 0.13646781406341454, Train Accuracy: 0.9074, Valid Accuracy: 0.6250
# Epoch 117, Loss 0.15812741945951414, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 118, Loss 0.18552194745876852, Train Accuracy: 0.8889, Valid Accuracy: 0.6250
# Epoch 119, Loss 0.18927480414127693, Train Accuracy: 0.9074, Valid Accuracy: 0.6250
# Epoch 120, Loss 0.1536849916745455, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 121, Loss 0.11437059403994145, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 122, Loss 0.1093491514523824, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 123, Loss 0.10421075156101814, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 124, Loss 0.10110829121027237, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 125, Loss 0.10434317283141308, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 126, Loss 0.1535653135715387, Train Accuracy: 0.8889, Valid Accuracy: 0.6250
# Epoch 127, Loss 0.12180914863561973, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 128, Loss 0.13833127648402482, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 129, Loss 0.13095016987659994, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 130, Loss 0.10040399546806629, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 131, Loss 0.10110817582179339, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 132, Loss 0.1135941254786956, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 133, Loss 0.09981978856600247, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 134, Loss 0.09367421651497865, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 135, Loss 0.09122105745168832, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 136, Loss 0.08366055748401544, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 137, Loss 0.0770634960096616, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 138, Loss 0.07449792249080463, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 139, Loss 0.07609733117696567, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 140, Loss 0.07858322942868257, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 141, Loss 0.0849837506046662, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 142, Loss 0.08116657229570243, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 143, Loss 0.10302684971919426, Train Accuracy: 0.9259, Valid Accuracy: 0.6250
# Epoch 144, Loss 0.0882636098525463, Train Accuracy: 0.9444, Valid Accuracy: 0.6250
# Epoch 145, Loss 0.06817617711539452, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 146, Loss 0.0847925060452559, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 147, Loss 0.06749743127670044, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 148, Loss 0.06434949258199105, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 149, Loss 0.053132040139574274, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 150, Loss 0.06435244988936645, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 151, Loss 0.058307747810314864, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 152, Loss 0.047909146891190454, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 153, Loss 0.05134105166563621, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 154, Loss 0.04653847914857742, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 155, Loss 0.049826365059767015, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 156, Loss 0.06162688883546835, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 157, Loss 0.05336794983118008, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 158, Loss 0.04337021823112781, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 159, Loss 0.05174925283361704, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 160, Loss 0.04197218479254307, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 161, Loss 0.04528621545968912, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 162, Loss 0.05940711526916577, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 163, Loss 0.0379267787704101, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 164, Loss 0.054230679877293415, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 165, Loss 0.046105523713124104, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 166, Loss 0.05431130920083095, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 167, Loss 0.04124011108890558, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 168, Loss 0.04002868517851218, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 169, Loss 0.034098194959836126, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 170, Loss 0.035940380146106087, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 171, Loss 0.034552266677984826, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 172, Loss 0.032608830298368745, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 173, Loss 0.030024829583290297, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 174, Loss 0.034046255434170745, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 175, Loss 0.04634564369916916, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 176, Loss 0.04771025918233089, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 177, Loss 0.04866290254852711, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 178, Loss 0.05108963707700754, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 179, Loss 0.03814753421988243, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 180, Loss 0.04378628625701635, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 181, Loss 0.030540208117319986, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 182, Loss 0.033690753703316055, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 183, Loss 0.031521546439482614, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 184, Loss 0.04297707879390472, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 185, Loss 0.043092600810222134, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 186, Loss 0.05290024709672882, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 187, Loss 0.07646619773302706, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 188, Loss 0.0654961964688622, Train Accuracy: 0.9815, Valid Accuracy: 0.7500
# Epoch 189, Loss 0.12951726955958667, Train Accuracy: 0.9074, Valid Accuracy: 0.6250
# Epoch 190, Loss 0.051740494676125355, Train Accuracy: 0.9630, Valid Accuracy: 0.6250
# Epoch 191, Loss 0.037128656099622064, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 192, Loss 0.028781916086490337, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 193, Loss 0.03302513382946833, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 194, Loss 0.02582679068048795, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 195, Loss 0.03807193198456214, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 196, Loss 0.03300009987866267, Train Accuracy: 0.9815, Valid Accuracy: 0.6250
# Epoch 197, Loss 0.023005995374077406, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 198, Loss 0.028283192680623286, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 199, Loss 0.022590665051188223, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Test Accuracy: 0.5000
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Loss 0.48379794756571454, Train Accuracy: 0.4444, Valid Accuracy: 0.6250
# Epoch 1, Loss 0.4802527626355489, Train Accuracy: 0.5741, Valid Accuracy: 0.6250
# Epoch 2, Loss 0.4782909735655173, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 3, Loss 0.47784233246094143, Train Accuracy: 0.5185, Valid Accuracy: 0.5000
# Epoch 4, Loss 0.478128330829816, Train Accuracy: 0.5556, Valid Accuracy: 0.5000
# Epoch 5, Loss 0.47707685293295443, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 6, Loss 0.476538740671598, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 7, Loss 0.47662041737483096, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 8, Loss 0.4785804794384883, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 9, Loss 0.4743120135405125, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.47857440129304546, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 11, Loss 0.4759022639347957, Train Accuracy: 0.5556, Valid Accuracy: 0.5000
# Epoch 12, Loss 0.47483103856062275, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.4805780053138733, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 14, Loss 0.47203527352748775, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 15, Loss 0.47037035379654324, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 16, Loss 0.4724122346975865, Train Accuracy: 0.7037, Valid Accuracy: 0.6250
# Epoch 17, Loss 0.4689113069803287, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 18, Loss 0.4672884986950801, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 19, Loss 0.46813605687557125, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 20, Loss 0.463712840508192, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 21, Loss 0.4634776879579593, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 22, Loss 0.46232047294959044, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 23, Loss 0.46486368698951525, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 24, Loss 0.45705216511701924, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 25, Loss 0.45476849873860675, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 26, Loss 0.4524483283360799, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 27, Loss 0.4512389546785599, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 28, Loss 0.4567546126170036, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 29, Loss 0.4604522020388872, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 30, Loss 0.4423943926126529, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 31, Loss 0.4424791687574142, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 32, Loss 0.4360417708372458, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 33, Loss 0.4412470352955354, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 34, Loss 0.4411284755437802, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 35, Loss 0.4359777875435658, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 36, Loss 0.4301832639254056, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 37, Loss 0.4295362631479899, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 38, Loss 0.47280966624235493, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 39, Loss 0.4690427642602187, Train Accuracy: 0.5741, Valid Accuracy: 0.6250
# Epoch 40, Loss 0.4484529082591717, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 41, Loss 0.43755842325014943, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 42, Loss 0.43309339040364975, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 43, Loss 0.43248467720471895, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 44, Loss 0.4315459315593426, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 45, Loss 0.44879655960278636, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 46, Loss 0.4173396642391498, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 47, Loss 0.4178724273657187, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 48, Loss 0.41525954466599685, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 49, Loss 0.42192640671363246, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 50, Loss 0.4009227080222888, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 51, Loss 0.42071512265083116, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 52, Loss 0.412750319028512, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 53, Loss 0.42251637195929503, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 54, Loss 0.3932764759430519, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 55, Loss 0.4014578048999493, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 56, Loss 0.3846333791048099, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 57, Loss 0.38328951597213745, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 58, Loss 0.4480321453167842, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 59, Loss 0.42455954964344317, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 60, Loss 0.41006516034786517, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 61, Loss 0.3850487042696048, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 62, Loss 0.38310416692342514, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 63, Loss 0.3733678956826528, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 64, Loss 0.3893922704916734, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 65, Loss 0.4309982894322811, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 66, Loss 0.40289165729131454, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 67, Loss 0.3942710428665846, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 68, Loss 0.37357783776063186, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 69, Loss 0.3727960005784646, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 70, Loss 0.394022952287625, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 71, Loss 0.39559760231238145, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 72, Loss 0.3523608278005551, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 73, Loss 0.3545850775180719, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 74, Loss 0.34941799671222, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 75, Loss 0.3616332625731444, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 76, Loss 0.3432470292617113, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 77, Loss 0.34525680465575975, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 78, Loss 0.3305537341496883, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 79, Loss 0.32828917717322326, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 80, Loss 0.36454959251941776, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 81, Loss 0.32514685545212185, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 82, Loss 0.3306564077352866, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 83, Loss 0.30458298249122423, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 84, Loss 0.33592566771384996, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 85, Loss 0.3211564941283984, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 86, Loss 0.3211503204626915, Train Accuracy: 0.7963, Valid Accuracy: 0.3750
# Epoch 87, Loss 0.32018479857689297, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 88, Loss 0.31670075349318677, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 89, Loss 0.2998335850544465, Train Accuracy: 0.8333, Valid Accuracy: 0.3750
# Epoch 90, Loss 0.34109603059597504, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 91, Loss 0.32669254220449007, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 92, Loss 0.30032274203422743, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 93, Loss 0.26967150889910185, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 94, Loss 0.2737887528462288, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 95, Loss 0.27449786510222995, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 96, Loss 0.2736340058155549, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 97, Loss 0.25935783714820176, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 98, Loss 0.287495752175649, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 99, Loss 0.24872829898809776, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 100, Loss 0.24789239198733598, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 101, Loss 0.25613283499693257, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 102, Loss 0.3185608501617725, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 103, Loss 0.24391324741718096, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 104, Loss 0.414074393419119, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 105, Loss 0.2943239846290686, Train Accuracy: 0.7963, Valid Accuracy: 0.3750
# Epoch 106, Loss 0.33633151879677403, Train Accuracy: 0.7407, Valid Accuracy: 0.3750
# Epoch 107, Loss 0.3109059914564475, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 108, Loss 0.23586097741738343, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 109, Loss 0.2670923494375669, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 110, Loss 0.3275145697288024, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 111, Loss 0.265659226056857, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 112, Loss 0.2375624623054113, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 113, Loss 0.2448186049094567, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 114, Loss 0.22773637106785408, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 115, Loss 0.25469822073594117, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 116, Loss 0.27236279386740464, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 117, Loss 0.2784001372563533, Train Accuracy: 0.8333, Valid Accuracy: 0.2500
# Epoch 118, Loss 0.3334063704197223, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 119, Loss 0.2722949232810583, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 120, Loss 0.3073744689806914, Train Accuracy: 0.7407, Valid Accuracy: 0.3750
# Epoch 121, Loss 0.29214325088721055, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 122, Loss 0.3904779370014484, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 123, Loss 0.26031235853830975, Train Accuracy: 0.8704, Valid Accuracy: 0.5000
# Epoch 124, Loss 0.23143340761844927, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 125, Loss 0.2044462569248982, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 126, Loss 0.25187150713724965, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 127, Loss 0.20672125273790115, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 128, Loss 0.205417968523808, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 129, Loss 0.2103864772197528, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 130, Loss 0.1853991464162484, Train Accuracy: 0.8889, Valid Accuracy: 0.3750
# Epoch 131, Loss 0.2537635159798158, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 132, Loss 0.2100498542571679, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 133, Loss 0.21831902250265464, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 134, Loss 0.22257100122097212, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 135, Loss 0.2205823193757962, Train Accuracy: 0.8889, Valid Accuracy: 0.3750
# Epoch 136, Loss 0.18280683954556784, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 137, Loss 0.16828137941849539, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 138, Loss 0.20994837620319465, Train Accuracy: 0.8704, Valid Accuracy: 0.5000
# Epoch 139, Loss 0.2008210328909067, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 140, Loss 0.19122479817806146, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 141, Loss 0.1822279366927269, Train Accuracy: 0.9259, Valid Accuracy: 0.3750
# Epoch 142, Loss 0.26009478324498886, Train Accuracy: 0.8148, Valid Accuracy: 0.2500
# Epoch 143, Loss 0.27908401917188597, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 144, Loss 0.26404042541980743, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 145, Loss 0.1678651987742155, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 146, Loss 0.1954417694837619, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 147, Loss 0.21572408844263125, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 148, Loss 0.1844268731581859, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 149, Loss 0.16069156972643656, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 150, Loss 0.15566591956676581, Train Accuracy: 0.9259, Valid Accuracy: 0.3750
# Epoch 151, Loss 0.15139603194517967, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 152, Loss 0.14439966157078743, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 153, Loss 0.16330955502314445, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 154, Loss 0.14351340096730453, Train Accuracy: 0.9630, Valid Accuracy: 0.3750
# Epoch 155, Loss 0.138634266379552, Train Accuracy: 0.9444, Valid Accuracy: 0.5000
# Epoch 156, Loss 0.12794840469574317, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 157, Loss 0.1259939288481688, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 158, Loss 0.1595830779809218, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 159, Loss 0.12279681517527653, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 160, Loss 0.11385688725381325, Train Accuracy: 0.9630, Valid Accuracy: 0.3750
# Epoch 161, Loss 0.12915345911796278, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 162, Loss 0.14766494585917547, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 163, Loss 0.10908004870781532, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 164, Loss 0.0985249590415221, Train Accuracy: 0.9630, Valid Accuracy: 0.3750
# Epoch 165, Loss 0.10171861526293632, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 166, Loss 0.15769338760620508, Train Accuracy: 0.9074, Valid Accuracy: 0.3750
# Epoch 167, Loss 0.1580936767351933, Train Accuracy: 0.8519, Valid Accuracy: 0.5000
# Epoch 168, Loss 0.12817538739779058, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Epoch 169, Loss 0.11876591123067416, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 170, Loss 0.2108948956697415, Train Accuracy: 0.8704, Valid Accuracy: 0.5000
# Epoch 171, Loss 0.1419323396224242, Train Accuracy: 0.9259, Valid Accuracy: 0.3750
# Epoch 172, Loss 0.12949087833746886, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 173, Loss 0.13465229326333755, Train Accuracy: 0.9259, Valid Accuracy: 0.3750
# Epoch 174, Loss 0.10693244645610833, Train Accuracy: 0.9444, Valid Accuracy: 0.5000
# Epoch 175, Loss 0.08533644179503123, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 176, Loss 0.08318576359978089, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 177, Loss 0.11554549710872845, Train Accuracy: 0.9074, Valid Accuracy: 0.5000
# Epoch 178, Loss 0.08967853471254691, Train Accuracy: 0.9630, Valid Accuracy: 0.5000
# Epoch 179, Loss 0.0772897047110093, Train Accuracy: 1.0000, Valid Accuracy: 0.3750
# Epoch 180, Loss 0.07620004946604753, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 181, Loss 0.08184421941255912, Train Accuracy: 0.9630, Valid Accuracy: 0.3750
# Epoch 182, Loss 0.06468881418307622, Train Accuracy: 1.0000, Valid Accuracy: 0.3750
# Epoch 183, Loss 0.06020247152982614, Train Accuracy: 1.0000, Valid Accuracy: 0.3750
# Epoch 184, Loss 0.0657839023340971, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 185, Loss 0.07036167268569653, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 186, Loss 0.08361397836452876, Train Accuracy: 0.9815, Valid Accuracy: 0.5000
# Epoch 187, Loss 0.08647410839031903, Train Accuracy: 0.9630, Valid Accuracy: 0.3750
# Epoch 188, Loss 0.06461994923078097, Train Accuracy: 1.0000, Valid Accuracy: 0.3750
# Epoch 189, Loss 0.06575672462200507, Train Accuracy: 1.0000, Valid Accuracy: 0.3750
# Epoch 190, Loss 0.08739998841132873, Train Accuracy: 0.9815, Valid Accuracy: 0.5000
# Epoch 191, Loss 0.07802508160089835, Train Accuracy: 0.9444, Valid Accuracy: 0.3750
# Epoch 192, Loss 0.07287302995339417, Train Accuracy: 0.9815, Valid Accuracy: 0.3750
# Epoch 193, Loss 0.2190051025305039, Train Accuracy: 0.8333, Valid Accuracy: 0.3750
# Epoch 194, Loss 0.49758639549597716, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 195, Loss 0.587515727067605, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 196, Loss 0.6342578045068643, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 197, Loss 0.24870494237312904, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 198, Loss 0.15555001757083795, Train Accuracy: 0.8889, Valid Accuracy: 0.5000
# Epoch 199, Loss 0.13089944135684234, Train Accuracy: 0.9259, Valid Accuracy: 0.5000
# Test Accuracy: 0.6250
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Loss 0.4827745388715695, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 1, Loss 0.4834634875639891, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 2, Loss 0.48034040285990787, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 3, Loss 0.4791267972726088, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 4, Loss 0.479063474214994, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 5, Loss 0.47998497424981534, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 6, Loss 0.4787996885104057, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 7, Loss 0.4780724048614502, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 8, Loss 0.4797436915911161, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 9, Loss 0.47731455778464293, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.4775353761819693, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.47740199779852843, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.4772532383600871, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.476460337638855, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 14, Loss 0.4760619982694968, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 15, Loss 0.4746458667975206, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 16, Loss 0.47643463428203875, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 17, Loss 0.4749977053740086, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 18, Loss 0.4756709260818286, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 19, Loss 0.47358819460257506, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 20, Loss 0.4779025132839496, Train Accuracy: 0.6481, Valid Accuracy: 0.6250
# Epoch 21, Loss 0.4712368341592642, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 22, Loss 0.46899047876015687, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 23, Loss 0.4717186643527104, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 24, Loss 0.4683252909244635, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 25, Loss 0.4668338161248427, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 26, Loss 0.46879430459095883, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 27, Loss 0.4648233957779713, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 28, Loss 0.4643197044348105, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 29, Loss 0.4629586216730949, Train Accuracy: 0.5741, Valid Accuracy: 0.2500
# Epoch 30, Loss 0.457600549245492, Train Accuracy: 0.5556, Valid Accuracy: 0.3750
# Epoch 31, Loss 0.45777742984967357, Train Accuracy: 0.5185, Valid Accuracy: 0.3750
# Epoch 32, Loss 0.4628189282539563, Train Accuracy: 0.4815, Valid Accuracy: 0.3750
# Epoch 33, Loss 0.44949736961951625, Train Accuracy: 0.5370, Valid Accuracy: 0.2500
# Epoch 34, Loss 0.4563179933107816, Train Accuracy: 0.5000, Valid Accuracy: 0.3750
# Epoch 35, Loss 0.45419818774247783, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 36, Loss 0.45037162151092136, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 37, Loss 0.44784868986178666, Train Accuracy: 0.5556, Valid Accuracy: 0.2500
# Epoch 38, Loss 0.45274403614875597, Train Accuracy: 0.5556, Valid Accuracy: 0.3750
# Epoch 39, Loss 0.4616640622799213, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 40, Loss 0.4381669988999, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 41, Loss 0.4739017012791756, Train Accuracy: 0.5556, Valid Accuracy: 0.2500
# Epoch 42, Loss 0.49060433644514817, Train Accuracy: 0.5556, Valid Accuracy: 0.6250
# Epoch 43, Loss 0.4548096595666347, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 44, Loss 0.449161844375806, Train Accuracy: 0.5741, Valid Accuracy: 0.1250
# Epoch 45, Loss 0.4460443166586069, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 46, Loss 0.440138992590782, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 47, Loss 0.437543803300613, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 48, Loss 0.4313950859583341, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 49, Loss 0.44754666090011597, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 50, Loss 0.4263494228705382, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 51, Loss 0.42508635306969667, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 52, Loss 0.42187420068643033, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 53, Loss 0.42072934141525853, Train Accuracy: 0.5926, Valid Accuracy: 0.2500
# Epoch 54, Loss 0.4224910445702382, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 55, Loss 0.4213310908048581, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 56, Loss 0.4327144317137889, Train Accuracy: 0.5741, Valid Accuracy: 0.2500
# Epoch 57, Loss 0.4085132372684968, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 58, Loss 0.4124120764243297, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 59, Loss 0.412326040940407, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 60, Loss 0.4185788249358153, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 61, Loss 0.4085139464109372, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 62, Loss 0.3961681991051405, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 63, Loss 0.40002554960739917, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 64, Loss 0.39503653997030014, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 65, Loss 0.40345654426476896, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 66, Loss 0.3935585969533676, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 67, Loss 0.3951440102014786, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 68, Loss 0.3923546656584128, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 69, Loss 0.38128986343359333, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 70, Loss 0.3754177681910686, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 71, Loss 0.3737750083972246, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 72, Loss 0.36838941772778827, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 73, Loss 0.3842695049750499, Train Accuracy: 0.7407, Valid Accuracy: 0.3750
# Epoch 74, Loss 0.3679617085517981, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 75, Loss 0.36487793846008104, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 76, Loss 0.3573261468838423, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 77, Loss 0.34424679707258177, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 78, Loss 0.34940863725466603, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 79, Loss 0.39062671325145626, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 80, Loss 0.38586879617128617, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 81, Loss 0.3702517870144966, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 82, Loss 0.3338714104432326, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 83, Loss 0.35501115597211397, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 84, Loss 0.4016201954621535, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 85, Loss 0.32755552652554637, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 86, Loss 0.36498448634758973, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 87, Loss 0.358768234650294, Train Accuracy: 0.7407, Valid Accuracy: 0.3750
# Epoch 88, Loss 0.36314267072922146, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 89, Loss 0.3007642198831607, Train Accuracy: 0.7593, Valid Accuracy: 0.2500
# Epoch 90, Loss 0.3364985310114347, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 91, Loss 0.3261632384398045, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 92, Loss 0.3332111743780283, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 93, Loss 0.3160027716404352, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 94, Loss 0.2973294632557111, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 95, Loss 0.3215248256157606, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 96, Loss 0.30546576243180495, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 97, Loss 0.3235176862814488, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 98, Loss 0.3039973890170073, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 99, Loss 0.2804768803792122, Train Accuracy: 0.8333, Valid Accuracy: 0.3750
# Epoch 100, Loss 0.280354394362523, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 101, Loss 0.2740731147619394, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 102, Loss 0.27160607775052387, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 103, Loss 0.27336666064384657, Train Accuracy: 0.8333, Valid Accuracy: 0.3750
# Epoch 104, Loss 0.24949477039850676, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 105, Loss 0.29828426318290907, Train Accuracy: 0.8148, Valid Accuracy: 0.2500
# Epoch 106, Loss 0.37335558579518247, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 107, Loss 0.2788382065601838, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 108, Loss 0.272678500184646, Train Accuracy: 0.8148, Valid Accuracy: 0.3750
# Epoch 109, Loss 0.2452433040508857, Train Accuracy: 0.8704, Valid Accuracy: 0.3750
# Epoch 110, Loss 0.25366112971917176, Train Accuracy: 0.8519, Valid Accuracy: 0.3750
# Epoch 111, Loss 0.2596224194917923, Train Accuracy: 0.8148, Valid Accuracy: 0.5000
# Epoch 112, Loss 0.3048790632150112, Train Accuracy: 0.8333, Valid Accuracy: 0.5000
# Epoch 113, Loss 0.327761084605486, Train Accuracy: 0.7407, Valid Accuracy: 0.6250
# Epoch 114, Loss 0.3299019168584775, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# ...
# Epoch 9, Loss 0.48745450148215663, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.48651491984342915, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.48625898590454686, Train Accuracy: 0.5455, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.48548216697497243, Train Accuracy: 0.5455, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.48455196848282445, Train Accuracy: 0.5455, Valid Accuracy: 0.7500
# Epoch 14, Loss 0.48519728428278214, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 15, Loss 0.4858322411011427, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 16, Loss 0.4855102231869331, Train Accuracy: 0.4727, Valid Accuracy: 0.6250
# Epoch 17, Loss 0.47982072600951564, Train Accuracy: 0.5455, Valid Accuracy: 0.7500
# Epoch 18, Loss 0.4940801866543599, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 19, Loss 0.4881791334885817, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 20, Loss 0.4846324553856483, Train Accuracy: 0.4727, Valid Accuracy: 0.3750
# Epoch 21, Loss 0.48273793779886687, Train Accuracy: 0.5273, Valid Accuracy: 0.7500
# Epoch 22, Loss 0.4823786432926471, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 23, Loss 0.48144386059198624, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 24, Loss 0.479693869749705, Train Accuracy: 0.5636, Valid Accuracy: 0.5000
# Epoch 25, Loss 0.4736714798670549, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 26, Loss 0.4777649763302925, Train Accuracy: 0.6364, Valid Accuracy: 0.5000
# Epoch 27, Loss 0.4719442358383766, Train Accuracy: 0.5273, Valid Accuracy: 0.5000
# Epoch 28, Loss 0.4684755626397255, Train Accuracy: 0.5636, Valid Accuracy: 0.5000
# Epoch 29, Loss 0.4680483593390538, Train Accuracy: 0.6364, Valid Accuracy: 0.6250
# Epoch 30, Loss 0.46324760027420825, Train Accuracy: 0.5636, Valid Accuracy: 0.6250
# Epoch 31, Loss 0.46347964650545365, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 32, Loss 0.45231485748902345, Train Accuracy: 0.5818, Valid Accuracy: 0.7500
# Epoch 33, Loss 0.4550429934110397, Train Accuracy: 0.5636, Valid Accuracy: 0.6250
# Epoch 34, Loss 0.4551933530049446, Train Accuracy: 0.5455, Valid Accuracy: 0.7500
# Epoch 35, Loss 0.44750203612523204, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 36, Loss 0.4492117762565613, Train Accuracy: 0.6182, Valid Accuracy: 0.7500
# Epoch 37, Loss 0.4424240016020261, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 38, Loss 0.46688807621980327, Train Accuracy: 0.5273, Valid Accuracy: 0.6250
# Epoch 39, Loss 0.4913380764997922, Train Accuracy: 0.6000, Valid Accuracy: 0.7500
# Epoch 40, Loss 0.4927504673982278, Train Accuracy: 0.5091, Valid Accuracy: 0.3750
# Epoch 41, Loss 0.47111038596202165, Train Accuracy: 0.5455, Valid Accuracy: 0.6250
# Epoch 42, Loss 0.4656015321230277, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 43, Loss 0.4544531924602313, Train Accuracy: 0.6545, Valid Accuracy: 0.6250
# Epoch 44, Loss 0.4531487295260796, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 45, Loss 0.4502758727623866, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 46, Loss 0.4425277495995546, Train Accuracy: 0.5636, Valid Accuracy: 0.6250
# Epoch 47, Loss 0.4408926329551599, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 48, Loss 0.4328230191499759, Train Accuracy: 0.6182, Valid Accuracy: 0.6250
# Epoch 49, Loss 0.4534921921216525, Train Accuracy: 0.6182, Valid Accuracy: 0.7500
# Epoch 50, Loss 0.425595665207276, Train Accuracy: 0.6000, Valid Accuracy: 0.5000
# Epoch 51, Loss 0.4280567138622969, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 52, Loss 0.42245916105233705, Train Accuracy: 0.6545, Valid Accuracy: 0.6250
# Epoch 53, Loss 0.4228120942910512, Train Accuracy: 0.7273, Valid Accuracy: 0.7500
# Epoch 54, Loss 0.4199061447229141, Train Accuracy: 0.6000, Valid Accuracy: 0.7500
# Epoch 55, Loss 0.440246955706523, Train Accuracy: 0.5455, Valid Accuracy: 0.7500
# Epoch 56, Loss 0.46495177424871004, Train Accuracy: 0.6364, Valid Accuracy: 0.7500
# Epoch 57, Loss 0.4190151871014864, Train Accuracy: 0.6727, Valid Accuracy: 0.6250
# Epoch 58, Loss 0.41247929059542143, Train Accuracy: 0.6364, Valid Accuracy: 0.6250
# Epoch 59, Loss 0.4144470508282001, Train Accuracy: 0.7091, Valid Accuracy: 0.7500
# Epoch 60, Loss 0.40325570794252247, Train Accuracy: 0.6545, Valid Accuracy: 0.8750
# Epoch 61, Loss 0.4195889876439021, Train Accuracy: 0.6364, Valid Accuracy: 0.5000
# Epoch 62, Loss 0.3898081313341092, Train Accuracy: 0.7455, Valid Accuracy: 0.8750
# Epoch 63, Loss 0.3768516236390823, Train Accuracy: 0.6727, Valid Accuracy: 0.7500
# Epoch 64, Loss 0.3836090656427237, Train Accuracy: 0.7455, Valid Accuracy: 0.8750
# Epoch 65, Loss 0.38354809544025326, Train Accuracy: 0.7818, Valid Accuracy: 0.8750
# Epoch 66, Loss 0.383548046151797, Train Accuracy: 0.6909, Valid Accuracy: 0.7500
# Epoch 67, Loss 0.3798809120288262, Train Accuracy: 0.7636, Valid Accuracy: 0.7500
# Epoch 68, Loss 0.3593440537269299, Train Accuracy: 0.7636, Valid Accuracy: 0.7500
# Epoch 69, Loss 0.3639571338127821, Train Accuracy: 0.7636, Valid Accuracy: 0.6250
# Epoch 70, Loss 0.37040436306060887, Train Accuracy: 0.6727, Valid Accuracy: 0.6250
# Epoch 71, Loss 0.39036768139936984, Train Accuracy: 0.7455, Valid Accuracy: 0.7500
# Epoch 72, Loss 0.4080238407238936, Train Accuracy: 0.6364, Valid Accuracy: 0.7500
# Epoch 73, Loss 0.37629748307741606, Train Accuracy: 0.7636, Valid Accuracy: 0.7500
# Epoch 74, Loss 0.35675371075287843, Train Accuracy: 0.6909, Valid Accuracy: 0.7500
# Epoch 75, Loss 0.3385961651802063, Train Accuracy: 0.8182, Valid Accuracy: 0.6250
# Epoch 76, Loss 0.35233731147570485, Train Accuracy: 0.6909, Valid Accuracy: 0.6250
# Epoch 77, Loss 0.3146795194882613, Train Accuracy: 0.8000, Valid Accuracy: 0.7500
# Epoch 78, Loss 0.29407554941299635, Train Accuracy: 0.8364, Valid Accuracy: 0.6250
# Epoch 79, Loss 0.324099056995832, Train Accuracy: 0.8182, Valid Accuracy: 0.5000
# Epoch 80, Loss 0.3613611769217711, Train Accuracy: 0.7273, Valid Accuracy: 0.7500
# Epoch 81, Loss 0.3220665829303937, Train Accuracy: 0.7455, Valid Accuracy: 0.8750
# Epoch 82, Loss 0.29362929325837356, Train Accuracy: 0.8909, Valid Accuracy: 0.7500
# Epoch 83, Loss 0.2777152447364269, Train Accuracy: 0.8364, Valid Accuracy: 0.5000
# Epoch 84, Loss 0.25784264772366255, Train Accuracy: 0.8727, Valid Accuracy: 0.5000
# Epoch 85, Loss 0.26060105516360355, Train Accuracy: 0.8000, Valid Accuracy: 0.7500
# Epoch 86, Loss 0.24936292186761513, Train Accuracy: 0.8545, Valid Accuracy: 0.7500
# Epoch 87, Loss 0.28350761303534877, Train Accuracy: 0.8182, Valid Accuracy: 0.6250
# Epoch 88, Loss 0.26708894165662617, Train Accuracy: 0.8909, Valid Accuracy: 0.8750
# Epoch 89, Loss 0.343067552225712, Train Accuracy: 0.7455, Valid Accuracy: 0.6250
# Epoch 90, Loss 0.41168551796521896, Train Accuracy: 0.7818, Valid Accuracy: 0.6250
# Epoch 91, Loss 0.310869126365735, Train Accuracy: 0.7273, Valid Accuracy: 0.6250
# Epoch 92, Loss 0.2572316527366638, Train Accuracy: 0.8545, Valid Accuracy: 0.6250
# Epoch 93, Loss 0.2603680214438683, Train Accuracy: 0.8182, Valid Accuracy: 0.6250
# Epoch 94, Loss 0.23108325516566253, Train Accuracy: 0.8909, Valid Accuracy: 0.5000
# Epoch 95, Loss 0.2193360531177276, Train Accuracy: 0.8727, Valid Accuracy: 0.7500
# Epoch 96, Loss 0.21398018778134614, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 97, Loss 0.19627876312304765, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 98, Loss 0.2000277178027691, Train Accuracy: 0.8909, Valid Accuracy: 0.7500
# Epoch 99, Loss 0.21392853405231085, Train Accuracy: 0.8364, Valid Accuracy: 0.6250
# Epoch 100, Loss 0.19166336495142716, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 101, Loss 0.18051203474020347, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 102, Loss 0.21027536919483772, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 103, Loss 0.2563349268375299, Train Accuracy: 0.8364, Valid Accuracy: 0.5000
# Epoch 104, Loss 0.1800653216166374, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 105, Loss 0.18350274001176542, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 106, Loss 0.161038573544759, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 107, Loss 0.14964701837072006, Train Accuracy: 0.9273, Valid Accuracy: 0.6250
# Epoch 108, Loss 0.1516981724745188, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 109, Loss 0.1520332621458249, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 110, Loss 0.15989429178910378, Train Accuracy: 0.8909, Valid Accuracy: 0.6250
# Epoch 111, Loss 0.16793009753410632, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 112, Loss 0.17581800772593573, Train Accuracy: 0.8909, Valid Accuracy: 0.2500
# Epoch 113, Loss 0.1959346525180034, Train Accuracy: 0.8545, Valid Accuracy: 0.5000
# Epoch 114, Loss 0.17703396588181838, Train Accuracy: 0.8545, Valid Accuracy: 0.5000
# Epoch 115, Loss 0.16113016658868545, Train Accuracy: 0.9455, Valid Accuracy: 0.3750
# Epoch 116, Loss 0.15528502143346345, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 117, Loss 0.15654156700922892, Train Accuracy: 0.9455, Valid Accuracy: 0.7500
# Epoch 118, Loss 0.19979009834619668, Train Accuracy: 0.8909, Valid Accuracy: 0.6250
# Epoch 119, Loss 0.15729310325323007, Train Accuracy: 0.9455, Valid Accuracy: 0.3750
# Epoch 120, Loss 0.16796016349242285, Train Accuracy: 0.8727, Valid Accuracy: 0.6250
# Epoch 121, Loss 0.17065208634504905, Train Accuracy: 0.9091, Valid Accuracy: 0.6250
# Epoch 122, Loss 0.14808230025646013, Train Accuracy: 0.9273, Valid Accuracy: 0.6250
# Epoch 123, Loss 0.1442312758702498, Train Accuracy: 0.9273, Valid Accuracy: 0.7500
# Epoch 124, Loss 0.20757607389719057, Train Accuracy: 0.8909, Valid Accuracy: 0.5000
# Epoch 125, Loss 0.29407122349127746, Train Accuracy: 0.8545, Valid Accuracy: 0.5000
# Epoch 126, Loss 0.26299446181227, Train Accuracy: 0.7818, Valid Accuracy: 0.7500
# Epoch 127, Loss 0.38366547800027406, Train Accuracy: 0.8000, Valid Accuracy: 0.7500
# Epoch 128, Loss 0.3170715516958481, Train Accuracy: 0.7455, Valid Accuracy: 0.6250
# Epoch 129, Loss 0.22966635188995263, Train Accuracy: 0.8545, Valid Accuracy: 0.6250
# Epoch 130, Loss 0.17970931205229881, Train Accuracy: 0.8727, Valid Accuracy: 0.6250
# Epoch 131, Loss 0.15195676588859314, Train Accuracy: 0.9636, Valid Accuracy: 0.6250
# Epoch 132, Loss 0.1435962105408693, Train Accuracy: 0.9091, Valid Accuracy: 0.6250
# Epoch 133, Loss 0.12051473557949066, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 134, Loss 0.12578025727699965, Train Accuracy: 0.9273, Valid Accuracy: 0.6250
# Epoch 135, Loss 0.11804772068101627, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 136, Loss 0.11018822552301945, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 137, Loss 0.1109789300423402, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 138, Loss 0.1200457520973988, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 139, Loss 0.11350395205693367, Train Accuracy: 0.9636, Valid Accuracy: 0.6250
# Epoch 140, Loss 0.12783658389861768, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 141, Loss 0.09893367582788834, Train Accuracy: 0.9636, Valid Accuracy: 0.6250
# Epoch 142, Loss 0.10603686125996785, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 143, Loss 0.09784675379976249, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 144, Loss 0.10498699030050865, Train Accuracy: 0.9636, Valid Accuracy: 0.6250
# Epoch 145, Loss 0.10423936350987507, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 146, Loss 0.10693506686351238, Train Accuracy: 0.9455, Valid Accuracy: 0.6250
# Epoch 147, Loss 0.08975685139497121, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 148, Loss 0.0908780078857373, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 149, Loss 0.08757471159482613, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 150, Loss 0.09159911958835064, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 151, Loss 0.08816699736202374, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 152, Loss 0.09854530141903804, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 153, Loss 0.10661707531947356, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 154, Loss 0.12927144164076218, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 155, Loss 0.1078598243303788, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 156, Loss 0.09413714611377472, Train Accuracy: 0.9818, Valid Accuracy: 0.3750
# Epoch 157, Loss 0.1111388888496619, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 158, Loss 0.07223317619317617, Train Accuracy: 0.9818, Valid Accuracy: 0.6250
# Epoch 159, Loss 0.08730378231176963, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 160, Loss 0.1192788358968802, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 161, Loss 0.10392567715965785, Train Accuracy: 0.9455, Valid Accuracy: 0.6250
# Epoch 162, Loss 0.09606977217854598, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 163, Loss 0.08324251629603215, Train Accuracy: 0.9818, Valid Accuracy: 0.6250
# Epoch 164, Loss 0.10005433991169319, Train Accuracy: 0.9091, Valid Accuracy: 0.6250
# Epoch 165, Loss 0.07818887764826798, Train Accuracy: 0.9818, Valid Accuracy: 0.6250
# Epoch 166, Loss 0.08053577414307839, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 167, Loss 0.0607170280164633, Train Accuracy: 0.9818, Valid Accuracy: 0.6250
# Epoch 168, Loss 0.06048416422727781, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Epoch 169, Loss 0.06348295815480061, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 170, Loss 0.06936954086025555, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 171, Loss 0.1211980321468451, Train Accuracy: 0.9273, Valid Accuracy: 0.6250
# Epoch 172, Loss 0.08765110526329432, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 173, Loss 0.11130823252292779, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 174, Loss 0.19901815133217055, Train Accuracy: 0.8545, Valid Accuracy: 0.6250
# Epoch 175, Loss 0.097489996932638, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 176, Loss 0.1505655199289322, Train Accuracy: 0.9091, Valid Accuracy: 0.5000
# Epoch 177, Loss 0.11611513678844158, Train Accuracy: 0.9455, Valid Accuracy: 0.6250
# Epoch 178, Loss 0.10461193590592115, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 179, Loss 0.07021918897636426, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 180, Loss 0.08290835469961166, Train Accuracy: 0.9273, Valid Accuracy: 0.5000
# Epoch 181, Loss 0.06938735051796986, Train Accuracy: 0.9455, Valid Accuracy: 0.5000
# Epoch 182, Loss 0.05579294164020281, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 183, Loss 0.05220160896006303, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 184, Loss 0.0570917286289235, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 185, Loss 0.06509899190412118, Train Accuracy: 0.9818, Valid Accuracy: 0.6250
# Epoch 186, Loss 0.05460433989094618, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 187, Loss 0.07199546752067712, Train Accuracy: 0.9636, Valid Accuracy: 0.6250
# Epoch 188, Loss 0.05743459908243937, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Epoch 189, Loss 0.0401610007079748, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 190, Loss 0.06633062068468486, Train Accuracy: 0.9636, Valid Accuracy: 0.5000
# Epoch 191, Loss 0.0558273709164216, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 192, Loss 0.050336246784680926, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Epoch 193, Loss 0.0422474852261635, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Epoch 194, Loss 0.040652539485540144, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 195, Loss 0.03719275519968225, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Epoch 196, Loss 0.04115967688938746, Train Accuracy: 1.0000, Valid Accuracy: 0.6250
# Epoch 197, Loss 0.037439362647441715, Train Accuracy: 0.9818, Valid Accuracy: 0.5000
# Epoch 198, Loss 0.042171703794827826, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Epoch 199, Loss 0.033218333640923865, Train Accuracy: 1.0000, Valid Accuracy: 0.5000
# Test Accuracy: 0.4000
# Average Test Accuracy: 0.5225
# Max test accuracy: 0.6875
# Standard Deviation: 0.11683321445547923

# %%
cn = filter_group('CN')
ad = filter_group('AD')
print(len(ad))
# Out:
# 31
