# %%
from nilearn import datasets, plotting, image
import nibabel as nib
from nilearn.maskers import NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure
from nilearn.interfaces.fmriprep import load_confounds
import numpy as np
import os
import pandas as pd

import torch.nn.functional as F
from torch.nn import Sequential, Linear, ReLU, GRU, BatchNorm1d
from torch_geometric.nn import EdgeConv, GCNConv, GraphConv
from torch_geometric.nn import global_mean_pool
from torch_geometric.data import InMemoryDataset, Data, DataLoader
from torch_geometric.utils import from_networkx

import networkx as nx
from networkx.convert_matrix import from_numpy_array

import torch
from torch.nn import Linear, Parameter
from torch_geometric.nn import MessagePassing
import torch_geometric as tg

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

import wandb
import random
import functions as f
import torch
import torch.nn.functional as F
from torch_geometric.data import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool

# %%
#generate correlation functions
corr_matrices_root = 'ADNI_full/corr_matrices'
full_corr_path_list = sorted(os.listdir(corr_matrices_root))
corr_matrices_full = []
for i in range(len(full_corr_path_list)):
    path = os.path.join(corr_matrices_root, full_corr_path_list[i])
    corr_matrices_full.append(np.loadtxt(path, delimiter=','))

# %%
#generate the label files
labels_full = np.loadtxt('ADNI_full/label_full.csv', dtype=str, delimiter=',')

# %%
##remove "SMC" values
idx = f.filter_SMC_patient_info()
corr_matrices = [corr_matrices_full[i] for i in idx]
labels = [labels_full[i] for i in idx]
for i in range(len(labels)):
    if labels[i] == 'CN':
        labels[i] = 0

    elif labels[i] == 'EMCI' or labels[i] == 'MCI' or labels[i] == 'LMCI':
        labels[i] = 1

    elif labels[i] == 'AD':
        labels[i] = 2

    else:
        print('Error: incorrect label')

# %%
#binary classification
cn = filter_group('CN')
ad = filter_group('AD')
bin_idx = sorted(cn + ad)
corr_matrices = [corr_matrices_full[i] for i in bin_idx]
labels = [labels_full[i] for i in bin_idx]
for i in range(len(labels)):
    if labels[i] == 'CN':
        labels[i] = 0

    elif labels[i] == 'AD':
        labels[i] = 1

    else:
        print('Error: incorrect label')

# %%
assert len(labels) == len(corr_matrices)

# %%
class ADNI_dataset(InMemoryDataset):
    def __init__(self, root, transform=None, pre_transform=None, threshold=0.4):
        self.threshold = threshold
        super().__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def processed_file_names(self):
        return ['data.pt']

    def process(self):
        """ Converts raw data into GNN-readable format by constructing
        graphs out of connectivity matrices.

        """
        graphs=[]
        for i in range(len(corr_matrices)):
            corr_matrix = corr_matrices[i]
            n_rois = corr_matrix.shape[0]
            edge_matrix = np.zeros((n_rois,n_rois))
            for j in range(n_rois):
                for k in range(n_rois):
                    if np.abs(corr_matrix[ j , k ]) < self.threshold:
                        edge_matrix[ j , k ] = 0
                    else:
                        edge_matrix[ j , k ] = corr_matrix[ j , k]

            corr_matrix_nx = from_numpy_array(edge_matrix)

            deg_dict = dict(corr_matrix_nx.degree())
            bc_dict = nx.betweenness_centrality(corr_matrix_nx)
            cc_dict = nx.clustering(corr_matrix_nx)
            # Compute the global efficiency of the graph
            ge = nx.global_efficiency(corr_matrix_nx)

            le_dict = {}

            # loop over all nodes in the graph
            for node in corr_matrix_nx.nodes():
                # find the subgraph of neighbors of the current node
                subgraph = corr_matrix_nx.subgraph(corr_matrix_nx.neighbors(node))

                # calculate the efficiency of the subgraph
                if subgraph.number_of_nodes() > 1:
                    efficiency = nx.global_efficiency(subgraph)
                else:
                    efficiency = 0.0

                # store the efficiency in the dictionary
                le_dict[node] = efficiency


            # Compute the participation coefficient and ratio of local to global efficiency of each node
            ratio_le_ge = np.array(list(le_dict.values())) / ge

            # Convert the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency dictionaries to NumPy arrays
            deg_array = np.array(list(deg_dict.values()))
            bc_array = np.array(list(bc_dict.values()))
            le_array = np.array(list(le_dict.values()))



            cc_array = np.array(list(cc_dict.values()))
            ratio_le_ge_array = ratio_le_ge

            # Normalize the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency arrays to have zero mean and unit variance
            deg_array_norm = (deg_array - np.mean(deg_array)) / np.std(deg_array)
            bc_array_norm = (bc_array - np.mean(bc_array)) / np.std(bc_array)
            le_array_norm = (le_array - np.mean(le_array)) / np.std(le_array)
            ratio_le_ge_array_norm = (ratio_le_ge_array - np.mean(ratio_le_ge_array)) / np.std(ratio_le_ge_array)
            cc_array_norm = (cc_array - np.mean(cc_array)) / np.std(cc_array)

            # Concatenate the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency arrays to form a single feature vector
            x_conc = torch.tensor(np.concatenate((deg_array_norm, bc_array_norm, le_array_norm, cc_array_norm, ratio_le_ge_array_norm)), dtype=torch.float)
            x = torch.reshape(x_conc , (5 , n_rois)).T


            corr_matrix_data = from_networkx(corr_matrix_nx)
            corr_matrix_data.x = x
            corr_matrix_data.y = labels[i]
            #pcorr_matrix_data.pos = coordinates

            # Add to running list of all dataset items
            graphs.append(corr_matrix_data)

        data, slices = self.collate(graphs)
        torch.save((data, slices), self.processed_paths[0])
# Out:
# 78

# %%
dataset = ADNI_dataset('ADNI_0.5')

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, dropout, input_dim ,output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, output_dim)
        self.dropout = dropout

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.relu(self.conv3(x, edge_index))
        x = global_mean_pool(x, batch)
        x = self.fc(x)
        return F.log_softmax(x, dim=1)
# Out:
# Processing...
# Dataset: ADNI_dataset(78):
# ====================
# Number of graphs: 78
# Number of features: 5
# Number of classes: 2
#
# Data(edge_index=[2, 8736], weight=[8736], x=[116, 5], y=[1], num_nodes=116)
# =============================================================
# Number of nodes: 116
# Number of edges: 8736
# Average node degree: 75.31
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Done!

# %%
def train():
    model.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
         #out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         out = model(data)
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.#
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
tot_test_acc = []
kf = StratifiedKFold(n_splits=5, shuffle=False)
for train_val_idx, test_idx in kf.split(dataset, dataset.data.y):
    X_train_val = [dataset[i] for i in train_val_idx]
    X_test      = [dataset[i] for i in test_idx]
    Y_train_val = [dataset.data.y[i] for i in train_val_idx]
    Y_test      = [dataset.data.y[i] for i in test_idx]

    X_train, X_valid, Y_train, Y_valid = train_test_split(X_train_val, Y_train_val , test_size=0.125,
                                                    random_state=42, stratify=Y_train_val)

    print(f'Number of training graphs: {len(X_train)}')
    print(f'Number of validation graphs: {len(X_valid)}')
    print(f'Number of test graphs: {len(X_test)}')

    lab = [0 , 1 , 2]
    class_freq = []
    for i in lab:
        class_freq.append(np.count_nonzero(torch.Tensor(Y_train) == i))
    class_freq = torch.FloatTensor(class_freq)
    class_weights = 1 / class_freq
    class_weights /= class_weights.sum()

    train_loader = DataLoader(X_train, batch_size=16, shuffle=True)
    valid_loader = DataLoader(X_valid, batch_size=len(X_valid), shuffle=True)
    test_loader = DataLoader(X_test, batch_size=len(X_test), shuffle=False)

    model = GCN(hidden_channels=8, dropout=0.5, input_dim=dataset.num_node_features, output_dim=dataset.num_classes)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

    model.train()
    for epoch in range(200):
        total_loss = 0
        for data in train_loader:
            optimizer.zero_grad()
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * data.num_graphs
            model.eval()
            correct = 0
            for data_v in valid_loader:
                out = model(data_v.x, data_v.edge_index, data_v.batch)
                pred = out.argmax(dim=1)
                print(pred)
                correct += int((pred == data_v.y).sum())
            acc = correct / len(valid_loader.dataset)
        print(f'Epoch {epoch}, Loss {total_loss / len(dataset)}, Valid Accuracy: {acc:.4f}')


    model.eval()
    correct = 0
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch)
        pred = out.argmax(dim=1)
        correct += int((pred == data.y).sum())
    acc = correct / len(test_loader.dataset)
    print(f'Test Accuracy: {acc:.4f}')
    tot_test_acc.append(acc)

print(f'Average Test Accuracy: {sum(tot_test_acc) / len(tot_test_acc)}')
print(f'Max test accuracy: {max(tot_test_acc)}')
print(f'Standard Deviation: {np.std(tot_test_acc)}')

# %%
def filter_group(group):
    df = pd.read_csv('/Users/georgepulickal/Documents/ADNI_FULL/patient_info.csv')
    labels = df['Research Group']
    label_idx_list = [i for i in range(len(labels)) if labels[i] == group]
    return label_idx_list
# Out:
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# Epoch 0, Loss 0.48230521648358077, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 1, Loss 0.4808824001214443, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 2, Loss 0.4810615869668814, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 3, Loss 0.4802932999072931, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 4, Loss 0.4798472202741183, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 5, Loss 0.4808482955663632, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 6, Loss 0.4803776129698142, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 7, Loss 0.47972614642901296, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 8, Loss 0.4795496479058877, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 9, Loss 0.48019154102374345, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.4796329996524713, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.4793496330579122, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.47962291882588315, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.48006828625996906, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 14, Loss 0.478815937653566, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 15, Loss 0.4796449664311531, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 16, Loss 0.4782154300273993, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 17, Loss 0.48056082083628726, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 18, Loss 0.4769956683501219, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 19, Loss 0.476795983620179, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 20, Loss 0.4791690447391608, Train Accuracy: 0.5370, Valid Accuracy: 0.5000
# Epoch 21, Loss 0.4784378271836501, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 22, Loss 0.47480014042976576, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 23, Loss 0.4752217622903677, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 24, Loss 0.4737649025061192, Train Accuracy: 0.5556, Valid Accuracy: 0.5000
# Epoch 25, Loss 0.47054329132422423, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 26, Loss 0.4699814778107863, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 27, Loss 0.46882018523338514, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 28, Loss 0.478090579693134, Train Accuracy: 0.5556, Valid Accuracy: 0.5000
# Epoch 29, Loss 0.4641748315248734, Train Accuracy: 0.5556, Valid Accuracy: 0.5000
# Epoch 30, Loss 0.46565674512814254, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 31, Loss 0.46659818826577604, Train Accuracy: 0.5370, Valid Accuracy: 0.5000
# Epoch 32, Loss 0.4557555440144661, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 33, Loss 0.4596331409918956, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 34, Loss 0.473729119851039, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 35, Loss 0.5003363352555495, Train Accuracy: 0.4630, Valid Accuracy: 0.3750
# Epoch 36, Loss 0.47321761265779155, Train Accuracy: 0.5185, Valid Accuracy: 0.5000
# Epoch 37, Loss 0.45919768779705733, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 38, Loss 0.46498070160547894, Train Accuracy: 0.6852, Valid Accuracy: 0.6250
# Epoch 39, Loss 0.4669521771944486, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 40, Loss 0.4598781053836529, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 41, Loss 0.4621065793893276, Train Accuracy: 0.5556, Valid Accuracy: 0.6250
# Epoch 42, Loss 0.4594747240726764, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 43, Loss 0.4671422518216647, Train Accuracy: 0.5556, Valid Accuracy: 0.3750
# Epoch 44, Loss 0.45392812673862165, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 45, Loss 0.45790999516462666, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 46, Loss 0.4547418386508257, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 47, Loss 0.44793022748751515, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 48, Loss 0.45582045194430226, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 49, Loss 0.45842139231852996, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 50, Loss 0.45217510675772643, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 51, Loss 0.45328475878788876, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 52, Loss 0.4564277193485162, Train Accuracy: 0.5556, Valid Accuracy: 0.6250
# Epoch 53, Loss 0.44590085133528096, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 54, Loss 0.455640957905696, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 55, Loss 0.43585204772460157, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 56, Loss 0.4541351290849539, Train Accuracy: 0.6667, Valid Accuracy: 0.6250
# Epoch 57, Loss 0.4680826037358015, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 58, Loss 0.4695072708985744, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 59, Loss 0.450407054179754, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 60, Loss 0.45489166180292767, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 61, Loss 0.44882823870732236, Train Accuracy: 0.5556, Valid Accuracy: 0.6250
# Epoch 62, Loss 0.47057881569251037, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 63, Loss 0.47286827594805986, Train Accuracy: 0.5370, Valid Accuracy: 0.5000
# Epoch 64, Loss 0.45848590441239184, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 65, Loss 0.44870522159796494, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 66, Loss 0.44963080607927763, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 67, Loss 0.4471106116588299, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 68, Loss 0.44071910167351747, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 69, Loss 0.45058447275406277, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 70, Loss 0.43824054797490436, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 71, Loss 0.4505324638806857, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 72, Loss 0.4410273218766237, Train Accuracy: 0.6481, Valid Accuracy: 0.6250
# Epoch 73, Loss 0.4387265474368364, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 74, Loss 0.43701698688360363, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 75, Loss 0.4444450124716147, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 76, Loss 0.43586152409895873, Train Accuracy: 0.6481, Valid Accuracy: 0.6250
# Epoch 77, Loss 0.4410746036431728, Train Accuracy: 0.7407, Valid Accuracy: 0.6250
# Epoch 78, Loss 0.4819811292183705, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 79, Loss 0.4336867729822795, Train Accuracy: 0.6111, Valid Accuracy: 0.5000
# Epoch 80, Loss 0.44496872333379894, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 81, Loss 0.4377431319310115, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 82, Loss 0.4434576920973949, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 83, Loss 0.4341445794472328, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 84, Loss 0.4412430861057379, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 85, Loss 0.4432095442062769, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 86, Loss 0.45596194114440525, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 87, Loss 0.4782098012092786, Train Accuracy: 0.5556, Valid Accuracy: 0.3750
# Epoch 88, Loss 0.43957172907315767, Train Accuracy: 0.5741, Valid Accuracy: 0.5000
# Epoch 89, Loss 0.4437130414522611, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 90, Loss 0.43846830802086073, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 91, Loss 0.4432189907783117, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 92, Loss 0.44120773138144076, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 93, Loss 0.42937672443878955, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 94, Loss 0.4398791041129675, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 95, Loss 0.42671639644182646, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 96, Loss 0.4272944743816669, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 97, Loss 0.4498803890668429, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 98, Loss 0.4382597804069519, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 99, Loss 0.4181587237578172, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 100, Loss 0.4293514459561079, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 101, Loss 0.41719402028964114, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 102, Loss 0.4231242736180623, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 103, Loss 0.41805580181953234, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 104, Loss 0.42709610401055753, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 105, Loss 0.43179649725938457, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 106, Loss 0.4112374560955243, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 107, Loss 0.41223862308722276, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 108, Loss 0.4141419774446732, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 109, Loss 0.4131426490270175, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 110, Loss 0.4096236824989319, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 111, Loss 0.4085274766653012, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 112, Loss 0.4223431570407672, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 113, Loss 0.440723995367686, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 114, Loss 0.441767475543878, Train Accuracy: 0.6296, Valid Accuracy: 0.6250
# Epoch 115, Loss 0.4761509406260955, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 116, Loss 0.4301372919327173, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 117, Loss 0.432688254576463, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 118, Loss 0.4194612151537186, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 119, Loss 0.41701481434015125, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 120, Loss 0.41800453571172863, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 121, Loss 0.42239168668404603, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 122, Loss 0.43538313951247776, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 123, Loss 0.4283275329149686, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 124, Loss 0.42274157511882293, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 125, Loss 0.4172073388711, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 126, Loss 0.41307312097304905, Train Accuracy: 0.6852, Valid Accuracy: 0.6250
# Epoch 127, Loss 0.4123023396883255, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 128, Loss 0.4049196441968282, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 129, Loss 0.4030489860436855, Train Accuracy: 0.7222, Valid Accuracy: 0.6250
# Epoch 130, Loss 0.4114960172237494, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 131, Loss 0.402790123071426, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 132, Loss 0.4241752349413358, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 133, Loss 0.431670497625302, Train Accuracy: 0.6296, Valid Accuracy: 0.5000
# Epoch 134, Loss 0.4019450392478552, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 135, Loss 0.4225136316739596, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 136, Loss 0.42612284421920776, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 137, Loss 0.41845491299262416, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 138, Loss 0.40414943756201327, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 139, Loss 0.4241908880380484, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 140, Loss 0.4119974542886783, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 141, Loss 0.4185706697977506, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 142, Loss 0.40639101847624165, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 143, Loss 0.4111464344538175, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 144, Loss 0.44172068895437777, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 145, Loss 0.3944364602749164, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 146, Loss 0.40723281028943187, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 147, Loss 0.42030175909017903, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 148, Loss 0.40182841741121733, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 149, Loss 0.3999834175293262, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 150, Loss 0.40136389166880876, Train Accuracy: 0.7778, Valid Accuracy: 0.5000
# Epoch 151, Loss 0.4114474531931755, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 152, Loss 0.39973575793779814, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 153, Loss 0.4002010852862627, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 154, Loss 0.39927308376018816, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 155, Loss 0.3933536387406863, Train Accuracy: 0.7593, Valid Accuracy: 0.3750
# Epoch 156, Loss 0.40715071176871276, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 157, Loss 0.4401896962752709, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 158, Loss 0.4822002527041313, Train Accuracy: 0.5741, Valid Accuracy: 0.6250
# Epoch 159, Loss 0.4187072286239037, Train Accuracy: 0.7222, Valid Accuracy: 0.6250
# Epoch 160, Loss 0.43010928233464557, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 161, Loss 0.4090455197370969, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 162, Loss 0.39966429196871245, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 163, Loss 0.4038837536787375, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 164, Loss 0.3939155768125485, Train Accuracy: 0.7407, Valid Accuracy: 0.3750
# Epoch 165, Loss 0.395955360852755, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 166, Loss 0.3947888964261764, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 167, Loss 0.44180220976853984, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 168, Loss 0.39363972498820377, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 169, Loss 0.4186971928828802, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 170, Loss 0.39412254859239626, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 171, Loss 0.40972786530470234, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 172, Loss 0.40801420655006015, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 173, Loss 0.39174496821868116, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 174, Loss 0.39915140928366244, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 175, Loss 0.3940478945389772, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 176, Loss 0.38973325338119114, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 177, Loss 0.3894974130850572, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 178, Loss 0.39760508063511973, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 179, Loss 0.3946580030979254, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 180, Loss 0.4261094836088327, Train Accuracy: 0.6667, Valid Accuracy: 0.5000
# Epoch 181, Loss 0.39079705415627897, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 182, Loss 0.38639215933970916, Train Accuracy: 0.7407, Valid Accuracy: 0.3750
# Epoch 183, Loss 0.392156740793815, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 184, Loss 0.4022734830012688, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 185, Loss 0.40974019582454974, Train Accuracy: 0.7037, Valid Accuracy: 0.5000
# Epoch 186, Loss 0.39106300396796984, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 187, Loss 0.38625343640645343, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 188, Loss 0.3853081258443686, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 189, Loss 0.39298953918310314, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 190, Loss 0.4036674805176564, Train Accuracy: 0.7593, Valid Accuracy: 0.5000
# Epoch 191, Loss 0.39373347086784166, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 192, Loss 0.4089120504183647, Train Accuracy: 0.7222, Valid Accuracy: 0.5000
# Epoch 193, Loss 0.38685545554527867, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 194, Loss 0.39858223306827056, Train Accuracy: 0.6852, Valid Accuracy: 0.5000
# Epoch 195, Loss 0.3967202596175365, Train Accuracy: 0.7407, Valid Accuracy: 0.5000
# Epoch 196, Loss 0.38607021631338656, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 197, Loss 0.3815564436790271, Train Accuracy: 0.7963, Valid Accuracy: 0.5000
# Epoch 198, Loss 0.39494202992854976, Train Accuracy: 0.7778, Valid Accuracy: 0.3750
# Epoch 199, Loss 0.38520851960548985, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Test Accuracy: 0.3750
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Loss 0.48190768712606186, Train Accuracy: 0.4074, Valid Accuracy: 0.3750
# Epoch 1, Loss 0.4796878374539889, Train Accuracy: 0.5370, Valid Accuracy: 0.6250
# Epoch 2, Loss 0.4796668336941646, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 3, Loss 0.4794876285088368, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 4, Loss 0.4797836954777057, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 5, Loss 0.47917452225318324, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 6, Loss 0.47937442859013873, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 7, Loss 0.4788787273260263, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 8, Loss 0.47848719358444214, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 9, Loss 0.4779148483887697, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.4769394657550714, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.47544792676583314, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.474458104524857, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.4728522056188339, Train Accuracy: 0.5926, Valid Accuracy: 0.5000
# Epoch 14, Loss 0.47143455957755065, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 15, Loss 0.4653852673677298, Train Accuracy: 0.6481, Valid Accuracy: 0.5000
# Epoch 16, Loss 0.46931362304932034, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 17, Loss 0.46171633708171356, Train Accuracy: 0.5556, Valid Accuracy: 0.2500
# Epoch 18, Loss 0.46028683582941693, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 19, Loss 0.4468798774939317, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 20, Loss 0.4586366980503767, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 21, Loss 0.4361274043718974, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 22, Loss 0.43522026905646694, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 23, Loss 0.43616788203899676, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 24, Loss 0.4199237395555545, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 25, Loss 0.4237257563150846, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 26, Loss 0.45297597157649505, Train Accuracy: 0.5370, Valid Accuracy: 0.3750
# Epoch 27, Loss 0.4447707014206128, Train Accuracy: 0.5741, Valid Accuracy: 0.2500
# Epoch 28, Loss 0.4031040974152394, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 29, Loss 0.43960284575437886, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 30, Loss 0.4164705001390897, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 31, Loss 0.4119416016798753, Train Accuracy: 0.5926, Valid Accuracy: 0.2500
# Epoch 32, Loss 0.41391835915736663, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 33, Loss 0.4031257491845351, Train Accuracy: 0.5926, Valid Accuracy: 0.3750
# Epoch 34, Loss 0.39077556133270264, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 35, Loss 0.4053601989379296, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 36, Loss 0.3845644073608594, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 37, Loss 0.40101616352032393, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 38, Loss 0.39758424881177074, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 39, Loss 0.39821538634789294, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 40, Loss 0.3791013803237524, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 41, Loss 0.38371231082158214, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 42, Loss 0.37707125223599947, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 43, Loss 0.3750618986594371, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 44, Loss 0.3772453528184157, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 45, Loss 0.4011017909416786, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 46, Loss 0.3800500570199428, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 47, Loss 0.4020488415008936, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 48, Loss 0.36701716520847416, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 49, Loss 0.38330391431466126, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 50, Loss 0.3607057760923337, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 51, Loss 0.3811626739991017, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 52, Loss 0.38066871502460575, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 53, Loss 0.3590303980387174, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 54, Loss 0.3828335052881485, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 55, Loss 0.3600822083460979, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 56, Loss 0.36823187348170155, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 57, Loss 0.35944776504467696, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 58, Loss 0.39303937019445956, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 59, Loss 0.3678923295094417, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 60, Loss 0.35842009079761994, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 61, Loss 0.37602799519514424, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 62, Loss 0.38087367705809766, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 63, Loss 0.35788913262196076, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 64, Loss 0.378519832323759, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 65, Loss 0.3614853223164876, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 66, Loss 0.3596729567417732, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 67, Loss 0.3586317155605707, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 68, Loss 0.351694507476611, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 69, Loss 0.35799248554767704, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 70, Loss 0.3617707383938325, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 71, Loss 0.3566878621394818, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 72, Loss 0.360118778852316, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 73, Loss 0.35274027784665424, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 74, Loss 0.38166369306735504, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 75, Loss 0.39247485460379183, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 76, Loss 0.37920237198854106, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 77, Loss 0.353245069583257, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 78, Loss 0.363857144728685, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 79, Loss 0.36823344230651855, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 80, Loss 0.36127989567243135, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 81, Loss 0.363037408162386, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 82, Loss 0.35451078567749417, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 83, Loss 0.3595262475502797, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 84, Loss 0.3609894063228216, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 85, Loss 0.38300581161792463, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 86, Loss 0.40297723580629397, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 87, Loss 0.3719597015625391, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 88, Loss 0.35439847065852237, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 89, Loss 0.35210614708753735, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 90, Loss 0.34704331786204606, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 91, Loss 0.3496771622926761, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 92, Loss 0.3485521796422127, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 93, Loss 0.3570634447611295, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 94, Loss 0.3516058065952399, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 95, Loss 0.3705544976087717, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 96, Loss 0.3587104892119383, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 97, Loss 0.3527984137718494, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 98, Loss 0.35877656630980664, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 99, Loss 0.34690939081020844, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 100, Loss 0.35532171603960866, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 101, Loss 0.3626637443518027, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 102, Loss 0.36143951232616717, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 103, Loss 0.3593337230193309, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 104, Loss 0.35857495207052964, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 105, Loss 0.35030793532347065, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 106, Loss 0.3498564714040512, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 107, Loss 0.35277268978265613, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 108, Loss 0.37946007954768646, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 109, Loss 0.37002536272391295, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 110, Loss 0.37799834670164645, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 111, Loss 0.3535933112486815, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 112, Loss 0.34776426813541317, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 113, Loss 0.35610809463721055, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 114, Loss 0.3641275320297632, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 115, Loss 0.4172126864775633, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 116, Loss 0.3776245621534494, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 117, Loss 0.409810633231432, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 118, Loss 0.3409807238823328, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 119, Loss 0.35675197686904514, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 120, Loss 0.3846176450069134, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 121, Loss 0.3568841264798091, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 122, Loss 0.3710016577671736, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 123, Loss 0.3564796738135509, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 124, Loss 0.3726727427580418, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 125, Loss 0.3484751383463542, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 126, Loss 0.34467879014137465, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 127, Loss 0.3485037860197899, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 128, Loss 0.34168253724391645, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 129, Loss 0.3398904445079657, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 130, Loss 0.3481170206497877, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 131, Loss 0.33943190635778964, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 132, Loss 0.3423206045841559, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 133, Loss 0.35205683952722794, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 134, Loss 0.36042120823493373, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 135, Loss 0.35917020837465924, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 136, Loss 0.3511359859735538, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 137, Loss 0.3529869547257057, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 138, Loss 0.34040051851517117, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 139, Loss 0.3455001543729733, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 140, Loss 0.3378857870896657, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 141, Loss 0.3401182553707025, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 142, Loss 0.3355819307840787, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 143, Loss 0.3525596612539047, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 144, Loss 0.38120344357612806, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 145, Loss 0.3570992419352898, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 146, Loss 0.3809759479302626, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 147, Loss 0.437195557814378, Train Accuracy: 0.5741, Valid Accuracy: 0.2500
# Epoch 148, Loss 0.3857582845748999, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 149, Loss 0.3486625918975243, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 150, Loss 0.354268946708777, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 151, Loss 0.34983791678379744, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 152, Loss 0.3455381592114766, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 153, Loss 0.335118707938072, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 154, Loss 0.3368110343431815, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 155, Loss 0.33437633972901565, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 156, Loss 0.3406810011619177, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 157, Loss 0.3500677408316197, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 158, Loss 0.34847092169981736, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 159, Loss 0.32967289441671127, Train Accuracy: 0.7222, Valid Accuracy: 0.2500
# Epoch 160, Loss 0.34503427682778776, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 161, Loss 0.3408364523679782, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 162, Loss 0.3341033183611356, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 163, Loss 0.3381508053877415, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 164, Loss 0.3380519403861119, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 165, Loss 0.3377619630251175, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 166, Loss 0.3418649817124391, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 167, Loss 0.33938672221623933, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 168, Loss 0.33060470147010607, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 169, Loss 0.3653181340449896, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 170, Loss 0.343367752356407, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 171, Loss 0.33517775932947796, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 172, Loss 0.33677267416929585, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 173, Loss 0.33691294835164, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 174, Loss 0.33502978468552613, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 175, Loss 0.34762914669819367, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 176, Loss 0.3466595357809311, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 177, Loss 0.3473381109726735, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 178, Loss 0.33494863983912343, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 179, Loss 0.37019890470382494, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 180, Loss 0.3451930024685004, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 181, Loss 0.3585165983591324, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 182, Loss 0.3459427845783723, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 183, Loss 0.3354539840649336, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 184, Loss 0.34105309003438705, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 185, Loss 0.3365504481853583, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 186, Loss 0.33269294943564975, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 187, Loss 0.33945722992603594, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 188, Loss 0.34275952592874187, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 189, Loss 0.3528728286425273, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 190, Loss 0.34352861917935884, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 191, Loss 0.3505675326555203, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 192, Loss 0.3391245939792731, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 193, Loss 0.3325151006380717, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 194, Loss 0.33905817912175107, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 195, Loss 0.34331078559924394, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 196, Loss 0.3415246032751523, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Epoch 197, Loss 0.3328301646770575, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 198, Loss 0.3383508981802525, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 199, Loss 0.33459347792160815, Train Accuracy: 0.7037, Valid Accuracy: 0.3750
# Test Accuracy: 0.3750
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/georgepulickal/PycharmProjects/Alzheimers/venv/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Loss 0.4825754761695862, Train Accuracy: 0.5741, Valid Accuracy: 0.6250
# Epoch 1, Loss 0.4790782210154411, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 2, Loss 0.4797294552509601, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 3, Loss 0.47815039677497667, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 4, Loss 0.4782070884337792, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 5, Loss 0.47730509898601436, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 6, Loss 0.4784016120128142, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 7, Loss 0.47681389710842037, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 8, Loss 0.4745718515836276, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 9, Loss 0.47417634419905835, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.4740215616348462, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.4714495906463036, Train Accuracy: 0.6111, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.470158902498392, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 13, Loss 0.4675217316700862, Train Accuracy: 0.5926, Valid Accuracy: 0.6250
# Epoch 14, Loss 0.465328927223499, Train Accuracy: 0.5741, Valid Accuracy: 0.3750
# Epoch 15, Loss 0.4625287178235176, Train Accuracy: 0.6111, Valid Accuracy: 0.3750
# Epoch 16, Loss 0.4537063317421155, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 17, Loss 0.452437087511405, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 18, Loss 0.461580155751644, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 19, Loss 0.4469689314181988, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 20, Loss 0.4357362985610962, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 21, Loss 0.43400660997782, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 22, Loss 0.4317544530599545, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 23, Loss 0.42521109336461776, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 24, Loss 0.4157175146616422, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 25, Loss 0.42908760676017177, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 26, Loss 0.4186403980621925, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 27, Loss 0.42404212859960705, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 28, Loss 0.41906879116327334, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 29, Loss 0.4305888827030475, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 30, Loss 0.4069359302520752, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 31, Loss 0.4060454857655061, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 32, Loss 0.40793354847492314, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 33, Loss 0.42094869644213945, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 34, Loss 0.4113909411124694, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 35, Loss 0.40657549790847, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 36, Loss 0.4043937952090532, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 37, Loss 0.4161250866376437, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 38, Loss 0.400691813383347, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 39, Loss 0.40269375917239064, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 40, Loss 0.399994242649812, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 41, Loss 0.397369445898594, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 42, Loss 0.40558207952059233, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 43, Loss 0.39568867591711193, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 44, Loss 0.4120421012242635, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 45, Loss 0.40750008668655, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 46, Loss 0.39881011079519224, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 47, Loss 0.4027252625196408, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 48, Loss 0.3996602029372484, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 49, Loss 0.39976563514807284, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 50, Loss 0.4151988617884807, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 51, Loss 0.4242231723589775, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 52, Loss 0.41299975071197903, Train Accuracy: 0.6111, Valid Accuracy: 0.2500
# Epoch 53, Loss 0.41197733695690447, Train Accuracy: 0.6296, Valid Accuracy: 0.2500
# Epoch 54, Loss 0.3928947639770997, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 55, Loss 0.40602130003464526, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 56, Loss 0.41652281467731184, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 57, Loss 0.3976920858407632, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 58, Loss 0.3927024862705133, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 59, Loss 0.39823640921177006, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 60, Loss 0.4140061323459332, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 61, Loss 0.4132176209718753, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 62, Loss 0.3918782014113206, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 63, Loss 0.40014816858829594, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 64, Loss 0.39530308582843876, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 65, Loss 0.39913119490330035, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 66, Loss 0.3926162750293047, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 67, Loss 0.38699191350203294, Train Accuracy: 0.7407, Valid Accuracy: 0.2500
# Epoch 68, Loss 0.39338846237231523, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 69, Loss 0.40050059709793484, Train Accuracy: 0.7222, Valid Accuracy: 0.2500
# Epoch 70, Loss 0.39189710372533554, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 71, Loss 0.3914573406561827, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 72, Loss 0.3918579014448019, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 73, Loss 0.3878467694306985, Train Accuracy: 0.7222, Valid Accuracy: 0.2500
# Epoch 74, Loss 0.3926037488839565, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 75, Loss 0.3865744257584596, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 76, Loss 0.39555011957119673, Train Accuracy: 0.6852, Valid Accuracy: 0.1250
# Epoch 77, Loss 0.3918390105932187, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 78, Loss 0.3749826535200461, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 79, Loss 0.3834113646776248, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 80, Loss 0.38051447654381776, Train Accuracy: 0.7037, Valid Accuracy: 0.1250
# Epoch 81, Loss 0.39412902945127243, Train Accuracy: 0.7222, Valid Accuracy: 0.2500
# Epoch 82, Loss 0.3773774321262653, Train Accuracy: 0.7037, Valid Accuracy: 0.1250
# Epoch 83, Loss 0.3894680264668587, Train Accuracy: 0.6852, Valid Accuracy: 0.2500
# Epoch 84, Loss 0.3860397002635858, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 85, Loss 0.37381704915792513, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 86, Loss 0.37258078654607135, Train Accuracy: 0.7407, Valid Accuracy: 0.2500
# Epoch 87, Loss 0.3867592704601777, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 88, Loss 0.3735864995381771, Train Accuracy: 0.6481, Valid Accuracy: 0.1250
# Epoch 89, Loss 0.3967830599882664, Train Accuracy: 0.6852, Valid Accuracy: 0.3750
# Epoch 90, Loss 0.37514777061266774, Train Accuracy: 0.6667, Valid Accuracy: 0.2500
# Epoch 91, Loss 0.3751830886571835, Train Accuracy: 0.7037, Valid Accuracy: 0.1250
# Epoch 92, Loss 0.39106491895822376, Train Accuracy: 0.6667, Valid Accuracy: 0.3750
# Epoch 93, Loss 0.39144650178077894, Train Accuracy: 0.6667, Valid Accuracy: 0.1250
# Epoch 94, Loss 0.3720589983157622, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 95, Loss 0.3934009701777727, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 96, Loss 0.3991430355952336, Train Accuracy: 0.7222, Valid Accuracy: 0.1250
# Epoch 97, Loss 0.38422088133983123, Train Accuracy: 0.7222, Valid Accuracy: 0.3750
# Epoch 98, Loss 0.39651586535649425, Train Accuracy: 0.6667, Valid Accuracy: 0.1250
# Epoch 99, Loss 0.36398973296850157, Train Accuracy: 0.7963, Valid Accuracy: 0.2500
# Epoch 100, Loss 0.37205181060693204, Train Accuracy: 0.6481, Valid Accuracy: 0.2500
# Epoch 101, Loss 0.3737620329245543, Train Accuracy: 0.7037, Valid Accuracy: 0.1250
# Epoch 102, Loss 0.3953747306114588, Train Accuracy: 0.6481, Valid Accuracy: 0.3750
# Epoch 103, Loss 0.3618132288639362, Train Accuracy: 0.7407, Valid Accuracy: 0.2500
# Epoch 104, Loss 0.3707094796192952, Train Accuracy: 0.7407, Valid Accuracy: 0.1250
# Epoch 105, Loss 0.3726003704926906, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 106, Loss 0.40558378360210323, Train Accuracy: 0.6481, Valid Accuracy: 0.1250
# Epoch 107, Loss 0.3892453419856536, Train Accuracy: 0.6296, Valid Accuracy: 0.3750
# Epoch 108, Loss 0.3886315134855417, Train Accuracy: 0.5926, Valid Accuracy: 0.2500
# Epoch 109, Loss 0.38846448828012514, Train Accuracy: 0.7222, Valid Accuracy: 0.1250
# Epoch 110, Loss 0.3751193208572192, Train Accuracy: 0.7593, Valid Accuracy: 0.1250
# Epoch 111, Loss 0.36514564202382016, Train Accuracy: 0.7407, Valid Accuracy: 0.1250
# Epoch 112, Loss 0.3760683177373348, Train Accuracy: 0.7778, Valid Accuracy: 0.2500
# Epoch 113, Loss 0.365755353982632, Train Accuracy: 0.7037, Valid Accuracy: 0.2500
# Epoch 114, Loss 0.36374216660475117, Train Accuracy: 0.7407, Valid Accuracy: 0.1250
# Epoch 115, Loss 0.37156041233967513, Train Accuracy: 0.7407, Valid Accuracy: 0.1250
# ...
# Epoch 9, Loss 0.4883481325247349, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 10, Loss 0.48836656029407793, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 11, Loss 0.4885291610008631, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 12, Loss 0.48833676943412196, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 13, Loss 0.48795791849111897, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 14, Loss 0.48842771618794173, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 15, Loss 0.48794443408648175, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 16, Loss 0.4878172400670174, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 17, Loss 0.48750895032515895, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 18, Loss 0.4877749918363033, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 19, Loss 0.48797600467999774, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 20, Loss 0.48789365933491635, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 21, Loss 0.4875623507377429, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 22, Loss 0.48751340004114, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 23, Loss 0.487521740870598, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 24, Loss 0.4859228997658461, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 25, Loss 0.4874504682345268, Train Accuracy: 0.5636, Valid Accuracy: 0.7500
# Epoch 26, Loss 0.4869297345479329, Train Accuracy: 0.6182, Valid Accuracy: 0.6250
# Epoch 27, Loss 0.4859115848174462, Train Accuracy: 0.5273, Valid Accuracy: 0.7500
# Epoch 28, Loss 0.4851237665384244, Train Accuracy: 0.5636, Valid Accuracy: 0.6250
# Epoch 29, Loss 0.48401180903116864, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 30, Loss 0.48376132280398637, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 31, Loss 0.4841685959926018, Train Accuracy: 0.5636, Valid Accuracy: 0.7500
# Epoch 32, Loss 0.4856051137814155, Train Accuracy: 0.4909, Valid Accuracy: 0.3750
# Epoch 33, Loss 0.4871093164651822, Train Accuracy: 0.5455, Valid Accuracy: 0.6250
# Epoch 34, Loss 0.4802046028467325, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 35, Loss 0.48204221633764416, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 36, Loss 0.47840377000662, Train Accuracy: 0.5818, Valid Accuracy: 0.6250
# Epoch 37, Loss 0.47887026499479246, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 38, Loss 0.4773898415076427, Train Accuracy: 0.5091, Valid Accuracy: 0.6250
# Epoch 39, Loss 0.47365529185686356, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 40, Loss 0.48341726569029003, Train Accuracy: 0.4364, Valid Accuracy: 0.2500
# Epoch 41, Loss 0.48107053072024614, Train Accuracy: 0.4909, Valid Accuracy: 0.3750
# Epoch 42, Loss 0.4653697426502521, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 43, Loss 0.4790493761881804, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 44, Loss 0.4825094059491769, Train Accuracy: 0.4727, Valid Accuracy: 0.3750
# Epoch 45, Loss 0.4905042373217069, Train Accuracy: 0.4000, Valid Accuracy: 0.3750
# Epoch 46, Loss 0.48989253013561934, Train Accuracy: 0.4000, Valid Accuracy: 0.3750
# Epoch 47, Loss 0.48965497888051546, Train Accuracy: 0.4000, Valid Accuracy: 0.2500
# Epoch 48, Loss 0.48820840777494967, Train Accuracy: 0.4727, Valid Accuracy: 0.3750
# Epoch 49, Loss 0.48846791952084273, Train Accuracy: 0.5273, Valid Accuracy: 0.6250
# Epoch 50, Loss 0.48438092072804767, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 51, Loss 0.4819973844748277, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 52, Loss 0.48159172137578327, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 53, Loss 0.47770615265919614, Train Accuracy: 0.6000, Valid Accuracy: 0.7500
# Epoch 54, Loss 0.475182117559971, Train Accuracy: 0.5636, Valid Accuracy: 0.6250
# Epoch 55, Loss 0.46883853811484116, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 56, Loss 0.4682398507228264, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 57, Loss 0.46926779319078493, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 58, Loss 0.4725158046453427, Train Accuracy: 0.5091, Valid Accuracy: 0.2500
# Epoch 59, Loss 0.476653543038246, Train Accuracy: 0.4727, Valid Accuracy: 0.3750
# Epoch 60, Loss 0.4627875678050212, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 61, Loss 0.4657074961906824, Train Accuracy: 0.5455, Valid Accuracy: 0.3750
# Epoch 62, Loss 0.4624867653235411, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 63, Loss 0.46434436165369475, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 64, Loss 0.4603668138002738, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 65, Loss 0.48556027351281583, Train Accuracy: 0.5091, Valid Accuracy: 0.3750
# Epoch 66, Loss 0.47075420235976195, Train Accuracy: 0.4909, Valid Accuracy: 0.2500
# Epoch 67, Loss 0.48173474883421874, Train Accuracy: 0.4727, Valid Accuracy: 0.2500
# Epoch 68, Loss 0.4692158286388104, Train Accuracy: 0.5273, Valid Accuracy: 0.5000
# Epoch 69, Loss 0.46400318848781097, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 70, Loss 0.4603468806315691, Train Accuracy: 0.6182, Valid Accuracy: 0.5000
# Epoch 71, Loss 0.45958913289583647, Train Accuracy: 0.5091, Valid Accuracy: 0.3750
# Epoch 72, Loss 0.4510344381515796, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 73, Loss 0.4565492998331021, Train Accuracy: 0.6000, Valid Accuracy: 0.5000
# Epoch 74, Loss 0.4531796215436397, Train Accuracy: 0.5455, Valid Accuracy: 0.5000
# Epoch 75, Loss 0.45041186458025223, Train Accuracy: 0.5455, Valid Accuracy: 0.3750
# Epoch 76, Loss 0.4600576613193903, Train Accuracy: 0.5455, Valid Accuracy: 0.5000
# Epoch 77, Loss 0.478279227629686, Train Accuracy: 0.4727, Valid Accuracy: 0.2500
# Epoch 78, Loss 0.4740794522640033, Train Accuracy: 0.5091, Valid Accuracy: 0.3750
# Epoch 79, Loss 0.4592795287951445, Train Accuracy: 0.5636, Valid Accuracy: 0.5000
# Epoch 80, Loss 0.4459703446198732, Train Accuracy: 0.6000, Valid Accuracy: 0.5000
# Epoch 81, Loss 0.4478613848869617, Train Accuracy: 0.5455, Valid Accuracy: 0.5000
# Epoch 82, Loss 0.4587952395280202, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 83, Loss 0.44363004962603253, Train Accuracy: 0.6182, Valid Accuracy: 0.5000
# Epoch 84, Loss 0.4598701856075189, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 85, Loss 0.44796811311672896, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 86, Loss 0.44081654839026624, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 87, Loss 0.4461740706211481, Train Accuracy: 0.6000, Valid Accuracy: 0.5000
# Epoch 88, Loss 0.44872358212104213, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 89, Loss 0.4405222367017697, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 90, Loss 0.4492531946072212, Train Accuracy: 0.6000, Valid Accuracy: 0.5000
# Epoch 91, Loss 0.43791799056224334, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 92, Loss 0.4534267683823903, Train Accuracy: 0.5636, Valid Accuracy: 0.5000
# Epoch 93, Loss 0.44319629974854297, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 94, Loss 0.440588361177689, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 95, Loss 0.43438138182346636, Train Accuracy: 0.6727, Valid Accuracy: 0.5000
# Epoch 96, Loss 0.436049284079136, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 97, Loss 0.4330721703859476, Train Accuracy: 0.6000, Valid Accuracy: 0.6250
# Epoch 98, Loss 0.45569583506156236, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 99, Loss 0.43858360862120604, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 100, Loss 0.4393563683216388, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 101, Loss 0.43494772376158297, Train Accuracy: 0.6364, Valid Accuracy: 0.5000
# Epoch 102, Loss 0.43484761470403427, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 103, Loss 0.44026464300277907, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 104, Loss 0.434100988583687, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 105, Loss 0.4448013718311603, Train Accuracy: 0.5636, Valid Accuracy: 0.3750
# Epoch 106, Loss 0.43957638282042283, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 107, Loss 0.4290405534780942, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 108, Loss 0.42995159595440596, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 109, Loss 0.4237672724784949, Train Accuracy: 0.6182, Valid Accuracy: 0.5000
# Epoch 110, Loss 0.43181749872672254, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 111, Loss 0.4374098074741853, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 112, Loss 0.4604971256011572, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 113, Loss 0.45789703039022595, Train Accuracy: 0.5636, Valid Accuracy: 0.2500
# Epoch 114, Loss 0.44181359425569194, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 115, Loss 0.4353582385258797, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 116, Loss 0.4395611332013057, Train Accuracy: 0.5818, Valid Accuracy: 0.5000
# Epoch 117, Loss 0.4203347303928473, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 118, Loss 0.42822806498943233, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 119, Loss 0.4272658748504443, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 120, Loss 0.42300323033944154, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 121, Loss 0.4217424637232071, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 122, Loss 0.42801250708408844, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 123, Loss 0.42277835653378415, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 124, Loss 0.420724698366263, Train Accuracy: 0.6545, Valid Accuracy: 0.6250
# Epoch 125, Loss 0.42714147231517696, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 126, Loss 0.42815939967448896, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 127, Loss 0.43430702770367646, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 128, Loss 0.424617160207186, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 129, Loss 0.45927285765990233, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 130, Loss 0.4660288874919598, Train Accuracy: 0.5091, Valid Accuracy: 0.2500
# Epoch 131, Loss 0.45532582432795793, Train Accuracy: 0.5091, Valid Accuracy: 0.3750
# Epoch 132, Loss 0.43080630057897323, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 133, Loss 0.43649000005844313, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 134, Loss 0.4458639239653563, Train Accuracy: 0.6182, Valid Accuracy: 0.6250
# Epoch 135, Loss 0.4450970307374612, Train Accuracy: 0.5636, Valid Accuracy: 0.2500
# Epoch 136, Loss 0.43574517048322237, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 137, Loss 0.41676915685335797, Train Accuracy: 0.6182, Valid Accuracy: 0.6250
# Epoch 138, Loss 0.43664855032395095, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 139, Loss 0.4176225157884451, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 140, Loss 0.4245508435444954, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 141, Loss 0.42095168699056673, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 142, Loss 0.42808427413304645, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 143, Loss 0.4228230600173657, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 144, Loss 0.4381768940350948, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 145, Loss 0.4292214482258528, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 146, Loss 0.4163820361479735, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 147, Loss 0.41994477006105274, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 148, Loss 0.4150374493537805, Train Accuracy: 0.7091, Valid Accuracy: 0.3750
# Epoch 149, Loss 0.4158355861138075, Train Accuracy: 0.6909, Valid Accuracy: 0.3750
# Epoch 150, Loss 0.4153072184477097, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 151, Loss 0.414277169184807, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 152, Loss 0.42662056516378355, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 153, Loss 0.4230311841536791, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 154, Loss 0.44707329685871416, Train Accuracy: 0.5636, Valid Accuracy: 0.5000
# Epoch 155, Loss 0.4323554535706838, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 156, Loss 0.4332830661382431, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 157, Loss 0.4191513206714239, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 158, Loss 0.41409092377393675, Train Accuracy: 0.6909, Valid Accuracy: 0.3750
# Epoch 159, Loss 0.41512876214125216, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 160, Loss 0.41414054616903645, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 161, Loss 0.4217206216775454, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 162, Loss 0.4347382997855162, Train Accuracy: 0.6000, Valid Accuracy: 0.5000
# Epoch 163, Loss 0.4687697574114188, Train Accuracy: 0.5091, Valid Accuracy: 0.2500
# Epoch 164, Loss 0.4759319967184311, Train Accuracy: 0.4727, Valid Accuracy: 0.2500
# Epoch 165, Loss 0.444618712633084, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 166, Loss 0.4277362196873396, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 167, Loss 0.4383844404648512, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 168, Loss 0.4107622783153485, Train Accuracy: 0.7091, Valid Accuracy: 0.3750
# Epoch 169, Loss 0.4242761073968349, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 170, Loss 0.4108148966080103, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 171, Loss 0.4114712660129254, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 172, Loss 0.41855359612367093, Train Accuracy: 0.6909, Valid Accuracy: 0.3750
# Epoch 173, Loss 0.4109816948572795, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 174, Loss 0.4090817356720949, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 175, Loss 0.41858836702811414, Train Accuracy: 0.6364, Valid Accuracy: 0.3750
# Epoch 176, Loss 0.4162043967308142, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 177, Loss 0.45569152327684254, Train Accuracy: 0.5273, Valid Accuracy: 0.2500
# Epoch 178, Loss 0.43864584886110747, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Epoch 179, Loss 0.4184195590324891, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 180, Loss 0.4321849659467355, Train Accuracy: 0.6000, Valid Accuracy: 0.2500
# Epoch 181, Loss 0.4257503526333051, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 182, Loss 0.4559270005959731, Train Accuracy: 0.5818, Valid Accuracy: 0.3750
# Epoch 183, Loss 0.43640679121017456, Train Accuracy: 0.5636, Valid Accuracy: 0.2500
# Epoch 184, Loss 0.4552731842566759, Train Accuracy: 0.5273, Valid Accuracy: 0.3750
# Epoch 185, Loss 0.42768736603932506, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 186, Loss 0.42523162334393233, Train Accuracy: 0.5636, Valid Accuracy: 0.2500
# Epoch 187, Loss 0.4467624884385329, Train Accuracy: 0.5636, Valid Accuracy: 0.2500
# Epoch 188, Loss 0.41715202652491057, Train Accuracy: 0.6364, Valid Accuracy: 0.5000
# Epoch 189, Loss 0.43112970697574127, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 190, Loss 0.4215291738510132, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 191, Loss 0.40869314930377865, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 192, Loss 0.4112560328764793, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 193, Loss 0.41359264040604615, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 194, Loss 0.41345576292429215, Train Accuracy: 0.6545, Valid Accuracy: 0.3750
# Epoch 195, Loss 0.40979054493781847, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 196, Loss 0.4138074570741409, Train Accuracy: 0.6182, Valid Accuracy: 0.3750
# Epoch 197, Loss 0.4076980818540622, Train Accuracy: 0.6909, Valid Accuracy: 0.3750
# Epoch 198, Loss 0.4175782646888342, Train Accuracy: 0.6727, Valid Accuracy: 0.3750
# Epoch 199, Loss 0.4563916753499936, Train Accuracy: 0.6000, Valid Accuracy: 0.3750
# Test Accuracy: 0.7333
# Average Test Accuracy: 0.5166666666666667
# Max test accuracy: 0.7333333333333333
# Standard Deviation: 0.13733576049635107

# %%
cn = filter_group('CN')
ad = filter_group('AD')
print(len(ad))
# Out:
# 31
